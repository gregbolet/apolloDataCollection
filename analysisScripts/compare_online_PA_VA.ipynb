# %%
import os
import argparse
import sys
import time
import pandas as pd
import re
from pathlib import Path

# %%
APOLLO_DATA_COLLECTION_DIR='/usr/WS2/bolet1/apolloDataCollection'
#APOLLO_DATA_COLLECTION_DIR='/g/g15/bolet1/workspace/apolloDataCollection/finalData/quartz/static_runs_no_traces'

# Open the PA and VA csv files
VAdf = pd.read_csv(APOLLO_DATA_COLLECTION_DIR+'/online-ETE-XTimeData_VA.csv')
PAdf = pd.read_csv(APOLLO_DATA_COLLECTION_DIR+'/online-ETE-XTimeData_PA.csv')

# %%
print(VAdf.shape)
print(PAdf.shape)
print(VAdf.columns)
# Out:
# (1811, 7)
# (1812, 7)
# Index(['progname', 'probSize', 'policy', 'minTrainData', 'trialnum',
#        'eteXtime', 'type'],
#       dtype='object')

# %%
print('Datasets loaded!')

# Join both datasets together into one
VAdf['type'] = 'VA'
PAdf['type'] = 'PA'

# Just one dataframe to worry about now
rawdf = pd.concat([VAdf, PAdf])
# Out:
# Datasets loaded!

# %%
# Let's preprocess and remove runs that don't have the same counts
grouped = rawdf.groupby(['progname', 'probSize', 'policy', 'minTrainData', 'type'])

#print(grouped['type'].count())
counts = grouped.count().reset_index()
print(counts)

# Separate the PAs from the VAs, then subtract
vas = counts.loc[counts['type'] == 'VA']
pas = counts.loc[counts['type'] == 'PA']

# Now let's merge the datasets s.t. we enforce matching trial counts
# this df has all the overlapping cases with the same trial count
# from VA and PA
filtered = pd.merge(vas, pas, how='inner', on=['progname', 'probSize', 'policy', 'minTrainData', 'trialnum', 'eteXtime'])

targets = filtered[['progname', 'probSize', 'policy', 'minTrainData']]

# Now let's filter out the parent dataframe
df = pd.merge(targets, rawdf, how='inner', on=['progname', 'probSize', 'minTrainData', 'policy'])
df = df.sort_values(by=['progname', 'probSize', 'policy', 'minTrainData', 'trialnum', 'type'])
print(df.head())
# Out:
#     progname   probSize                                       policy  \
# 0       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 1       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 2       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 3       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 4       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 5       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 6       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 7       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 8       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 9       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 10      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 11      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 12      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 13      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 14      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 15      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 16      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 17      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 18      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 19      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 20      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 21      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 22      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 23      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 24      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 25      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 26      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 27      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 28      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 29      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# ..       ...        ...                                          ...
# 854  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 855  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 856  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 857  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 858  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 859  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 860  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 861  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 862  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 863  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 864  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 865  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 866  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 867  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 868  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 869  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 870  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 871  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 872  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 873  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 874  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 875  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 876  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 877  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 878  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 879  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 880  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 881  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 882  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 883  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
#
#      minTrainData type  trialnum  eteXtime
# 0               3   PA         2         2
# 1               3   VA         2         2
# 2               6   PA         2         2
# 3               6   VA         2         2
# 4               9   PA         2         2
# 5               9   VA         2         2
# 6              12   PA         2         2
# 7              12   VA         2         2
# 8              15   PA         2         2
# 9              15   VA         2         2
# 10             18   PA         2         2
# 11             18   VA         2         2
# 12             21   PA         2         2
# 13             21   VA         2         2
# 14             24   PA         2         2
# 15             24   VA         2         2
# 16             27   PA         2         2
# 17             27   VA         2         2
# 18             30   PA         2         2
# 19             30   VA         2         2
# 20              3   PA         2         2
# 21              3   VA         2         2
# 22              6   PA         2         2
# 23              6   VA         2         2
# 24              9   PA         2         2
# 25              9   VA         2         2
# 26             12   PA         2         2
# 27             12   VA         2         2
# 28             15   PA         2         2
# 29             15   VA         2         2
# ..            ...  ...       ...       ...
# 854            18   PA         2         2
# 855            18   VA         2         2
# 856            21   PA         2         2
# 857            21   VA         2         2
# 858            24   PA         2         2
# 859            24   VA         2         2
# 860            27   PA         2         2
# 861            27   VA         2         2
# 862            30   PA         2         2
# 863            30   VA         2         2
# 864             3   PA         2         2
# 865             3   VA         2         2
# 866             6   PA         2         2
# 867             6   VA         2         2
# 868             9   PA         2         2
# 869             9   VA         2         2
# 870            12   PA         2         2
# 871            12   VA         2         2
# 872            15   PA         2         2
# 873            15   VA         2         2
# 874            18   PA         2         2
# 875            18   VA         2         2
# 876            21   PA         2         2
# 877            21   VA         2         2
# 878            24   PA         2         2
# 879            24   VA         2         2
# 880            27   PA         2         2
# 881            27   VA         2         2
# 882            30   PA         2         2
# 883            30   VA         2         2
#
# [884 rows x 7 columns]
#   progname   probSize                                       policy  \
# 2     comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 0     comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 3     comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 1     comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 6     comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
#
#    minTrainData  trialnum    eteXtime type
# 2             3         0  749.901565   PA
# 0             3         0  974.290347   VA
# 3             3         1  750.190965   PA
# 1             3         1  978.878550   VA
# 6             6         0  969.497032   PA

# %%
# Now that we've cleaned the dataset, lets calculate means
grouped = df.groupby(['progname', 'probSize', 'policy', 'minTrainData', 'type'])

# Compute avrg and stddev
means = grouped['eteXtime'].mean().reset_index()
stds = grouped['eteXtime'].std().reset_index()

summdf = means.copy()
summdf.drop('eteXtime', axis=1, inplace=True)

summdf['mean_etextime'] = means['eteXtime']
summdf['std_etextime'] = stds['eteXtime']

print(summdf)
# Out:
#     progname   probSize                                       policy  \
# 0       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 1       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 2       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 3       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 4       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 5       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 6       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 7       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 8       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 9       comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 10      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 11      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 12      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 13      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 14      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 15      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 16      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 17      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 18      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 19      comd  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 20      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 21      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 22      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 23      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 24      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 25      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 26      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 27      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 28      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 29      comd    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# ..       ...        ...                                          ...
# 852  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 853  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 854  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 855  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 856  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 857  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 858  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 859  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 860  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 861  xsbench    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 862  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 863  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 864  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 865  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 866  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 867  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 868  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 869  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 870  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 871  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 872  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 873  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 874  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 875  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 876  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 877  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 878  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 879  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 880  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 881  xsbench  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
#
#      minTrainData type  mean_etextime  std_etextime
# 0               3   PA     750.046265      0.204637
# 1               3   VA     976.584448      3.244350
# 2               6   PA     970.192466      0.983492
# 3               6   VA    7624.375320      3.862740
# 4               9   PA    1250.159356      1.877199
# 5               9   VA    7626.492571      9.896248
# 6              12   PA    1466.915343     23.017251
# 7              12   VA    7664.857651      9.811913
# 8              15   PA    1563.783380      2.809013
# 9              15   VA    7638.828275     30.016433
# 10             18   PA    1833.404500     22.024683
# 11             18   VA    7672.989235     14.547604
# 12             21   PA    2046.815156      0.667317
# 13             21   VA    7645.937596     27.857198
# 14             24   PA    2212.920215     64.602322
# 15             24   VA    7611.795193     14.512175
# 16             27   PA    2381.622211      0.588072
# 17             27   VA    7611.482960     31.809783
# 18             30   PA    2670.194481    112.610644
# 19             30   VA    7656.257061     37.374327
# 20              3   PA     101.565437      0.169682
# 21              3   VA     128.096635      0.213177
# 22              6   PA     126.919570      0.050039
# 23              6   VA     913.366983      0.248632
# 24              9   PA     150.638961      0.445780
# 25              9   VA     915.978225      2.153691
# 26             12   PA     184.186280      0.096885
# 27             12   VA     913.691278      2.866135
# 28             15   PA     199.237971      0.247227
# 29             15   VA     915.956114      1.697305
# ..            ...  ...            ...           ...
# 852            18   PA       4.985500      0.153442
# 853            18   VA       5.075500      0.002121
# 854            21   PA       5.022500      0.051619
# 855            21   VA       4.999500      0.017678
# 856            24   PA       4.982500      0.027577
# 857            24   VA       4.975000      0.029698
# 858            27   PA       4.945500      0.037477
# 859            27   VA       4.996000      0.053740
# 860            30   PA       5.031000      0.033941
# 861            30   VA       4.981500      0.026163
# 862             3   PA       0.810000      0.002828
# 863             3   VA       1.493000      0.001414
# 864             6   PA       1.494000      0.004243
# 865             6   VA       2.686000      0.000000
# 866             9   PA       2.061500      0.012021
# 867             9   VA       2.535000      0.004243
# 868            12   PA       2.160000      0.005657
# 869            12   VA       2.232500      0.003536
# 870            15   PA       2.248000      0.000000
# 871            15   VA       2.225000      0.001414
# 872            18   PA       2.249500      0.000707
# 873            18   VA       2.228000      0.008485
# 874            21   PA       2.246000      0.007071
# 875            21   VA       2.227000      0.001414
# 876            24   PA       2.243000      0.002828
# 877            24   VA       2.224500      0.000707
# 878            27   PA       2.253000      0.007071
# 879            27   VA       2.228000      0.001414
# 880            30   PA       2.246000      0.000000
# 881            30   VA       2.232000      0.002828
#
# [882 rows x 7 columns]

# %%
vadf = summdf.loc[summdf['type'] == 'VA']
padf = summdf.loc[summdf['type'] == 'PA']

vadf = vadf.sort_values(by=['progname', 'probSize', 'policy', 'minTrainData'])
padf = padf.sort_values(by=['progname', 'probSize', 'policy', 'minTrainData'])

# Now let's take the diffs between PA and VA mean xtimes
timeDiffs = padf['mean_etextime'].to_numpy() - vadf['mean_etextime'].to_numpy()

# If any values are greater than 0, then PA was slower
padf['pa_minus_va'] = timeDiffs
padf['va_mean_ete_xtime'] = vadf['mean_etextime'].to_numpy()

# Now let's get percent xtime diff
padf['perc_xtime_diff'] = (timeDiffs * 100) / (vadf['mean_etextime'].to_numpy())

padf = padf.sort_values(by=['perc_xtime_diff'])

print(padf)
# Out:
#         progname   probSize                                       policy  \
# 762  rodinia_lud  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 764  rodinia_lud  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 782  rodinia_lud    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 766  rodinia_lud  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 768  rodinia_lud  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 772  rodinia_lud  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 774  rodinia_lud  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 784  rodinia_lud    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 786  rodinia_lud    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 788  rodinia_lud    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 776  rodinia_lud  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 770  rodinia_lud  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 778  rodinia_lud  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 790  rodinia_lud    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 802  rodinia_lud  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 780  rodinia_lud  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 792  rodinia_lud    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 796  rodinia_lud    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 798  rodinia_lud    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 794  rodinia_lud    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 800  rodinia_lud    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 804  rodinia_lud  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 806  rodinia_lud  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 808  rodinia_lud  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 810  rodinia_lud  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 182       nas_bt  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 812  rodinia_lud  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 222       nas_bt  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 202       nas_bt    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 814  rodinia_lud  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# ..           ...        ...                                          ...
# 602  quicksilver    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 608  quicksilver    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 94        lulesh    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 582  quicksilver  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 580  quicksilver  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 610  quicksilver    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 624  quicksilver  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 630  quicksilver  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 82        lulesh    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 606  quicksilver    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 584  quicksilver  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 620  quicksilver  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 92        lulesh    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 60        lulesh  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 604  quicksilver    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 600  quicksilver    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 102       lulesh  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 114       lulesh  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 106       lulesh  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 104       lulesh  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 118       lulesh  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 112       lulesh  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 110       lulesh  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 108       lulesh  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 116       lulesh  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 80        lulesh    medprob  DecisionTree,max_depth=4,explore=RoundRobin
# 100       lulesh  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 632  quicksilver  smallprob  DecisionTree,max_depth=4,explore=RoundRobin
# 592  quicksilver  largeprob  DecisionTree,max_depth=4,explore=RoundRobin
# 612  quicksilver    medprob  DecisionTree,max_depth=4,explore=RoundRobin
#
#      minTrainData type  mean_etextime  std_etextime   pa_minus_va  \
# 762             3   PA     130.420455      2.124953  -5017.698734
# 764             6   PA     135.941557      3.997060  -4940.947495
# 782             3   PA      16.192770      0.245405   -565.734602
# 766             9   PA     144.361193      1.773135  -4888.478931
# 768            12   PA     153.137827      2.508576  -4929.381447
# 772            18   PA     168.921320      5.489138  -4821.537500
# 774            21   PA     175.142952      2.898306  -4647.661640
# 784             6   PA      18.892122      0.036189   -492.933837
# 786             9   PA      19.955951      0.261138   -503.924105
# 788            12   PA      21.701529      0.420366   -546.890348
# 776            24   PA     190.702946      2.940964  -4776.200208
# 770            15   PA     163.161800      4.267260  -3655.220279
# 778            27   PA     195.132610      3.004359  -4360.457933
# 790            15   PA      23.177937      0.639915   -506.146210
# 802             3   PA       0.265242      0.001869     -5.687655
# 780            30   PA     202.486930      1.333328  -4323.786332
# 792            18   PA      23.907461      0.611244   -477.367483
# 796            24   PA      27.891289      0.329695   -508.210880
# 798            27   PA      28.281295      0.783870   -505.563401
# 794            21   PA      27.004646      0.147024   -465.610208
# 800            30   PA      30.078337      2.078808   -493.979000
# 804             6   PA       0.333069      0.003623     -5.375564
# 806             9   PA       0.393367      0.001602     -5.271678
# 808            12   PA       0.456917      0.000219     -5.085889
# 810            15   PA       0.527550      0.006743     -4.734486
# 182             6   PA    1519.490000      4.143646 -12909.785000
# 812            18   PA       0.585149      0.005001     -4.596374
# 222             6   PA      19.310000      0.028284   -141.375000
# 202             6   PA      81.280000      3.252691   -582.215000
# 814            21   PA       0.643628      0.003985     -4.514227
# ..            ...  ...            ...           ...           ...
# 602             6   PA      60.447957      4.530882     16.204264
# 608            15   PA      60.113561      3.064608     16.200550
# 94             24   PA     296.874045      0.645383     81.175245
# 582             6   PA     125.994564     16.067070     34.455212
# 580             3   PA     116.907788      2.593206     33.268969
# 610            18   PA      61.424309      1.826846     17.601801
# 624             9   PA      33.265274      5.442146      9.699496
# 630            18   PA      34.453969      2.976342     10.047510
# 82              6   PA     281.224710      0.711943     85.620955
# 606            12   PA      64.467180      8.300249     19.905633
# 584             9   PA     130.941437      5.153002     42.303656
# 620             3   PA      31.841119      6.575278     10.524820
# 92             21   PA     301.047395      3.264875    103.047080
# 60              3   PA     489.015220      5.736969    167.416080
# 604             9   PA      72.297008      0.860059     28.693791
# 600             3   PA      66.108760      7.533886     26.827548
# 102             6   PA     151.757760      5.308944     70.759374
# 114            24   PA     149.356205      0.828694     73.172281
# 106            12   PA     148.923625      1.354230     76.464993
# 104             9   PA     149.391365      1.263352     77.088897
# 118            30   PA     149.396010      0.710388     78.244585
# 112            21   PA     148.240020      0.880419     78.600204
# 110            18   PA     150.016595      1.114619     80.162544
# 108            15   PA     150.782505      1.153086     81.891438
# 116            27   PA     151.618565      3.680088     85.842732
# 80              3   PA     427.084670      8.551650    272.622160
# 100             3   PA     309.892980      0.134930    221.826845
# 632            21   PA     146.400540      0.611759    110.359395
# 592            21   PA     586.418538      0.140109    449.096021
# 612            21   PA     293.009499      0.194780    225.886190
#
#      va_mean_ete_xtime  perc_xtime_diff
# 762        5148.119189       -97.466639
# 764        5076.889052       -97.322345
# 782         581.927371       -97.217390
# 766        5032.840124       -97.131616
# 768        5082.519275       -96.986970
# 772        4990.458821       -96.615114
# 774        4822.804593       -96.368442
# 784         511.825959       -96.308878
# 786         523.880056       -96.190741
# 788         568.591876       -96.183286
# 776        4966.903154       -96.160526
# 770        3818.382079       -95.726939
# 778        4555.590543       -95.716634
# 790         529.324146       -95.621221
# 802           5.952896       -95.544329
# 780        4526.273262       -95.526410
# 792         501.274945       -95.230669
# 796         536.102168       -94.797393
# 798         533.844696       -94.702337
# 794         492.614854       -94.518102
# 800         524.057337       -94.260487
# 804           5.708633       -94.165521
# 806           5.665045       -93.056242
# 808           5.542806       -91.756575
# 810           5.262036       -89.974413
# 182       14429.275000       -89.469395
# 812           5.181523       -88.707008
# 222         160.685000       -87.982699
# 202         663.495000       -87.749719
# 814           5.157854       -87.521409
# ..                 ...              ...
# 602          44.243693        36.625026
# 608          43.913011        36.892370
# 94          215.698800        37.633610
# 582          91.539352        37.639781
# 580          83.638819        39.776948
# 610          43.822508        40.166120
# 624          23.565779        41.159241
# 630          24.406458        41.167425
# 82          195.603755        43.772654
# 606          44.561546        44.669979
# 584          88.637781        47.726438
# 620          21.316298        49.374521
# 92          198.000315        52.043897
# 60          321.599140        52.057378
# 604          43.603217        65.806591
# 600          39.281212        68.296131
# 102          80.998387        87.358991
# 114          76.183924        96.046879
# 106          72.458632       105.529170
# 104          72.302468       106.620008
# 118          71.151425       109.969105
# 112          69.639816       112.866758
# 110          69.854051       114.757187
# 108          68.891067       118.870910
# 116          65.775832       130.508014
# 80          154.462510       176.497300
# 100          88.066135       251.886659
# 632          36.041145       306.203906
# 592         137.322517       327.037422
# 612          67.123309       336.524216
#
# [441 rows x 10 columns]

# %%
# now let's lookat the lulesh runs
#print(padf.loc[padf['progname'] == 'rodinia_lud'])

# Let's look at the outlier runs too
print(padf.loc[(padf['perc_xtime_diff'] <= -50) | (padf['perc_xtime_diff'] >= 50), 
               ['progname', 'probSize', 'minTrainData', 'perc_xtime_diff']])
# Out:
#         progname   probSize  minTrainData  perc_xtime_diff
# 762  rodinia_lud  largeprob             3       -97.466639
# 764  rodinia_lud  largeprob             6       -97.322345
# 782  rodinia_lud    medprob             3       -97.217390
# 766  rodinia_lud  largeprob             9       -97.131616
# 768  rodinia_lud  largeprob            12       -96.986970
# 772  rodinia_lud  largeprob            18       -96.615114
# 774  rodinia_lud  largeprob            21       -96.368442
# 784  rodinia_lud    medprob             6       -96.308878
# 786  rodinia_lud    medprob             9       -96.190741
# 788  rodinia_lud    medprob            12       -96.183286
# 776  rodinia_lud  largeprob            24       -96.160526
# 770  rodinia_lud  largeprob            15       -95.726939
# 778  rodinia_lud  largeprob            27       -95.716634
# 790  rodinia_lud    medprob            15       -95.621221
# 802  rodinia_lud  smallprob             3       -95.544329
# 780  rodinia_lud  largeprob            30       -95.526410
# 792  rodinia_lud    medprob            18       -95.230669
# 796  rodinia_lud    medprob            24       -94.797393
# 798  rodinia_lud    medprob            27       -94.702337
# 794  rodinia_lud    medprob            21       -94.518102
# 800  rodinia_lud    medprob            30       -94.260487
# 804  rodinia_lud  smallprob             6       -94.165521
# 806  rodinia_lud  smallprob             9       -93.056242
# 808  rodinia_lud  smallprob            12       -91.756575
# 810  rodinia_lud  smallprob            15       -89.974413
# 182       nas_bt  largeprob             6       -89.469395
# 812  rodinia_lud  smallprob            18       -88.707008
# 222       nas_bt  smallprob             6       -87.982699
# 202       nas_bt    medprob             6       -87.749719
# 814  rodinia_lud  smallprob            21       -87.521409
# ..           ...        ...           ...              ...
# 16          comd  largeprob            27       -68.710142
# 198       nas_bt  largeprob            30       -67.965644
# 54          comd  smallprob            24       -67.627260
# 36          comd    medprob            27       -66.993925
# 842      xsbench    medprob             3       -65.529230
# 18          comd  largeprob            30       -65.124023
# 56          comd  smallprob            27       -65.006133
# 38          comd    medprob            30       -64.464132
# 58          comd  smallprob            30       -61.612240
# 822      xsbench  largeprob             3       -58.095676
# 824      xsbench  largeprob             6       -52.445127
# 208       nas_bt    medprob            15       -51.023552
# 92        lulesh    medprob            21        52.043897
# 60        lulesh  largeprob             3        52.057378
# 604  quicksilver    medprob             9        65.806591
# 600  quicksilver    medprob             3        68.296131
# 102       lulesh  smallprob             6        87.358991
# 114       lulesh  smallprob            24        96.046879
# 106       lulesh  smallprob            12       105.529170
# 104       lulesh  smallprob             9       106.620008
# 118       lulesh  smallprob            30       109.969105
# 112       lulesh  smallprob            21       112.866758
# 110       lulesh  smallprob            18       114.757187
# 108       lulesh  smallprob            15       118.870910
# 116       lulesh  smallprob            27       130.508014
# 80        lulesh    medprob             3       176.497300
# 100       lulesh  smallprob             3       251.886659
# 632  quicksilver  smallprob            21       306.203906
# 592  quicksilver  largeprob            21       327.037422
# 612  quicksilver    medprob            21       336.524216
#
# [92 rows x 4 columns]
