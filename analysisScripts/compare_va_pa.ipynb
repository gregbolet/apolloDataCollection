# %%
import os
import argparse
import sys
import time
import pandas as pd
import re
from pathlib import Path

pd.set_option('display.max_rows', None)

APOLLO_DATA_COLLECTION_DIR='/usr/WS2/bolet1/apolloDataCollection'
APOLLO_DATA_COLLECTION_DIR='/g/g15/bolet1/workspace/apolloDataCollection/finalData/quartz/static_runs_no_traces'


# Open the PA and VA csv files
VAdf = pd.read_csv(APOLLO_DATA_COLLECTION_DIR+'/static-ETE-XTimeData_VA.csv')
PAdf = pd.read_csv(APOLLO_DATA_COLLECTION_DIR+'/static-ETE-XTimeData_PA.csv')

print('Datasets loaded!')

# Join both datasets together into one
VAdf['type'] = 'VA'
PAdf['type'] = 'PA'

# Just one dataframe to worry about now
rawdf = pd.concat([VAdf, PAdf])

# for now, let's only focus on runs with policy 0
#rawdf = rawdf.loc[rawdf['policy'] == "Static,policy=0"]
# let's drop some programs we don't care about
rawdf = rawdf.loc[rawdf['progname'] != "rodinia_backprop"]
rawdf = rawdf.loc[rawdf['progname'] != "rodinia_nn"]
rawdf = rawdf.loc[rawdf['progname'] != "rodinia_nw"]

# Let's preprocess and remove runs that don't have the same counts
grouped = rawdf.groupby(['progname', 'probSize', 'policy', 'type'])

#print(grouped['type'].count())
counts = grouped.count().reset_index()
print(counts)

# Separate the PAs from the VAs, then subtract
vas = counts.loc[counts['type'] == 'VA']
pas = counts.loc[counts['type'] == 'PA']

# Now let's merge the datasets s.t. we enforce matching trial counts
# this df has all the overlapping cases with the same trial count
# from VA and PA
filtered = pd.merge(vas, pas, how='inner', on=['progname', 'probSize', 'policy', 'trialnum', 'eteXtime'])

targets = filtered[['progname', 'probSize', 'policy']]

# Now let's filter out the parent dataframe
df = pd.merge(targets, rawdf, how='inner', on=['progname', 'probSize', 'policy'])
df = df.sort_values(by=['progname', 'probSize', 'policy', 'trialnum', 'type'])
print(df.head())

#df = df.loc[df['trialnum'] > 3]

# Now that we've cleaned the dataset, lets calculate means
grouped = df.groupby(['progname', 'probSize', 'policy', 'type'])

# Compute avrg and stddev
means = grouped['eteXtime'].mean().reset_index()
stds = grouped['eteXtime'].std().reset_index()

summdf = means.copy()
summdf.drop('eteXtime', axis=1, inplace=True)

summdf['mean_etextime'] = means['eteXtime']
summdf['std_etextime'] = stds['eteXtime']

print(summdf)

vadf = summdf.loc[summdf['type'] == 'VA']
padf = summdf.loc[summdf['type'] == 'PA']

vadf = vadf.sort_values(by=['progname', 'probSize', 'policy'])
padf = padf.sort_values(by=['progname', 'probSize', 'policy'])

# Now let's take the diffs between PA and VA mean xtimes
timeDiffs = padf['mean_etextime'].to_numpy() - vadf['mean_etextime'].to_numpy()

# If any values are greater than 0, then PA was slower
padf['pa_minus_va'] = timeDiffs
padf['va_mean_ete_xtime'] = vadf['mean_etextime'].to_numpy()

# Now let's get percent xtime diff
padf['perc_xtime_diff'] = (timeDiffs * 100) / (vadf['mean_etextime'].to_numpy())

padf = padf.sort_values(by=['perc_xtime_diff'])
# Out:
# Datasets loaded!
#                progname   probSize           policy type  trialnum  eteXtime
# 0                  comd  largeprob  Static,policy=0   PA        10        10
# 1                  comd  largeprob  Static,policy=0   VA        10        10
# 2                  comd  largeprob  Static,policy=1   PA        10        10
# 3                  comd  largeprob  Static,policy=1   VA        10        10
# 4                  comd  largeprob  Static,policy=2   PA         4         4
# 5                  comd  largeprob  Static,policy=2   VA         4         4
# 6                  comd    medprob  Static,policy=0   PA        10        10
# 7                  comd    medprob  Static,policy=0   VA        10        10
# 8                  comd    medprob  Static,policy=1   PA        10        10
# 9                  comd    medprob  Static,policy=1   VA        10        10
# 10                 comd    medprob  Static,policy=2   PA         4         4
# 11                 comd    medprob  Static,policy=2   VA         4         4
# 12                 comd  smallprob  Static,policy=0   PA        10        10
# 13                 comd  smallprob  Static,policy=0   VA        10        10
# 14                 comd  smallprob  Static,policy=1   PA        10        10
# 15                 comd  smallprob  Static,policy=1   VA        10        10
# 16                 comd  smallprob  Static,policy=2   PA         4         4
# 17                 comd  smallprob  Static,policy=2   VA         4         4
# 18               lulesh  largeprob  Static,policy=0   PA        10        10
# 19               lulesh  largeprob  Static,policy=0   VA        10        10
# 20               lulesh  largeprob  Static,policy=1   PA        10        10
# 21               lulesh  largeprob  Static,policy=1   VA        10        10
# 22               lulesh  largeprob  Static,policy=2   PA         4         4
# 23               lulesh  largeprob  Static,policy=2   VA         4         4
# 24               lulesh    medprob  Static,policy=0   PA        10        10
# 25               lulesh    medprob  Static,policy=0   VA        10        10
# 26               lulesh    medprob  Static,policy=1   PA        10        10
# 27               lulesh    medprob  Static,policy=1   VA        10        10
# 28               lulesh    medprob  Static,policy=2   PA         4         4
# 29               lulesh    medprob  Static,policy=2   VA         4         4
# 30               lulesh  smallprob  Static,policy=0   PA        10        10
# 31               lulesh  smallprob  Static,policy=0   VA        10        10
# 32               lulesh  smallprob  Static,policy=1   PA        10        10
# 33               lulesh  smallprob  Static,policy=1   VA        10        10
# 34               lulesh  smallprob  Static,policy=2   PA         4         4
# 35               lulesh  smallprob  Static,policy=2   VA         4         4
# 36               minife  largeprob  Static,policy=0   PA        10        10
# 37               minife  largeprob  Static,policy=0   VA        10        10
# 38               minife  largeprob  Static,policy=1   PA        10        10
# 39               minife  largeprob  Static,policy=1   VA        10        10
# 40               minife  largeprob  Static,policy=2   PA         4         4
# 41               minife  largeprob  Static,policy=2   VA         4         4
# 42               minife    medprob  Static,policy=0   PA        10        10
# 43               minife    medprob  Static,policy=0   VA        10        10
# 44               minife    medprob  Static,policy=1   PA        10        10
# 45               minife    medprob  Static,policy=1   VA        10        10
# 46               minife    medprob  Static,policy=2   PA         4         4
# 47               minife    medprob  Static,policy=2   VA         4         4
# 48               minife  smallprob  Static,policy=0   PA        10        10
# 49               minife  smallprob  Static,policy=0   VA        10        10
# 50               minife  smallprob  Static,policy=1   PA        10        10
# 51               minife  smallprob  Static,policy=1   VA        10        10
# 52               minife  smallprob  Static,policy=2   PA         4         4
# 53               minife  smallprob  Static,policy=2   VA         4         4
# 54               nas_bt  largeprob  Static,policy=0   PA        10        10
# 55               nas_bt  largeprob  Static,policy=0   VA        10        10
# 56               nas_bt  largeprob  Static,policy=1   PA        10        10
# 57               nas_bt  largeprob  Static,policy=1   VA        10        10
# 58               nas_bt  largeprob  Static,policy=2   PA         4         4
# 59               nas_bt  largeprob  Static,policy=2   VA         4         4
# 60               nas_bt    medprob  Static,policy=0   PA        10        10
# 61               nas_bt    medprob  Static,policy=0   VA        10        10
# 62               nas_bt    medprob  Static,policy=1   PA        10        10
# 63               nas_bt    medprob  Static,policy=1   VA        10        10
# 64               nas_bt    medprob  Static,policy=2   PA        10        10
# 65               nas_bt    medprob  Static,policy=2   VA        10        10
# 66               nas_bt  smallprob  Static,policy=0   PA        10        10
# 67               nas_bt  smallprob  Static,policy=0   VA        10        10
# 68               nas_bt  smallprob  Static,policy=1   PA        10        10
# 69               nas_bt  smallprob  Static,policy=1   VA        10        10
# 70               nas_bt  smallprob  Static,policy=2   PA        10        10
# 71               nas_bt  smallprob  Static,policy=2   VA        10        10
# 72               nas_cg  largeprob  Static,policy=0   PA        10        10
# 73               nas_cg  largeprob  Static,policy=0   VA        10        10
# 74               nas_cg  largeprob  Static,policy=1   PA        10        10
# 75               nas_cg  largeprob  Static,policy=1   VA        10        10
# 76               nas_cg  largeprob  Static,policy=2   PA        10        10
# 77               nas_cg  largeprob  Static,policy=2   VA        10        10
# 78               nas_cg    medprob  Static,policy=0   PA        10        10
# 79               nas_cg    medprob  Static,policy=0   VA        10        10
# 80               nas_cg    medprob  Static,policy=1   PA        10        10
# 81               nas_cg    medprob  Static,policy=1   VA        10        10
# 82               nas_cg    medprob  Static,policy=2   PA        10        10
# 83               nas_cg    medprob  Static,policy=2   VA        10        10
# 84               nas_cg  smallprob  Static,policy=0   PA        10        10
# 85               nas_cg  smallprob  Static,policy=0   VA        10        10
# 86               nas_cg  smallprob  Static,policy=1   PA        10        10
# 87               nas_cg  smallprob  Static,policy=1   VA        10        10
# 88               nas_cg  smallprob  Static,policy=2   PA        10        10
# 89               nas_cg  smallprob  Static,policy=2   VA        10        10
# 90               nas_ep  largeprob  Static,policy=0   PA        10        10
# 91               nas_ep  largeprob  Static,policy=0   VA        10        10
# 92               nas_ep  largeprob  Static,policy=1   PA        10        10
# 93               nas_ep  largeprob  Static,policy=1   VA        10        10
# 94               nas_ep  largeprob  Static,policy=2   PA        10        10
# 95               nas_ep  largeprob  Static,policy=2   VA        10        10
# 96               nas_ep    medprob  Static,policy=0   PA        10        10
# 97               nas_ep    medprob  Static,policy=0   VA        10        10
# 98               nas_ep    medprob  Static,policy=1   PA        10        10
# 99               nas_ep    medprob  Static,policy=1   VA        10        10
# 100              nas_ep    medprob  Static,policy=2   PA        10        10
# 101              nas_ep    medprob  Static,policy=2   VA        10        10
# 102              nas_ep  smallprob  Static,policy=0   PA        10        10
# 103              nas_ep  smallprob  Static,policy=0   VA        10        10
# 104              nas_ep  smallprob  Static,policy=1   PA        10        10
# 105              nas_ep  smallprob  Static,policy=1   VA        10        10
# 106              nas_ep  smallprob  Static,policy=2   PA        10        10
# 107              nas_ep  smallprob  Static,policy=2   VA        10        10
# 108              nas_ft  largeprob  Static,policy=0   PA        10        10
# 109              nas_ft  largeprob  Static,policy=0   VA        10        10
# 110              nas_ft  largeprob  Static,policy=1   PA        10        10
# 111              nas_ft  largeprob  Static,policy=1   VA        10        10
# 112              nas_ft  largeprob  Static,policy=2   PA        10        10
# 113              nas_ft  largeprob  Static,policy=2   VA        10        10
# 114              nas_ft    medprob  Static,policy=0   PA        10        10
# 115              nas_ft    medprob  Static,policy=0   VA        10        10
# 116              nas_ft    medprob  Static,policy=1   PA        10        10
# 117              nas_ft    medprob  Static,policy=1   VA        10        10
# 118              nas_ft    medprob  Static,policy=2   PA        10        10
# 119              nas_ft    medprob  Static,policy=2   VA        10        10
# 120              nas_ft  smallprob  Static,policy=0   PA        10        10
# 121              nas_ft  smallprob  Static,policy=0   VA        10        10
# 122              nas_ft  smallprob  Static,policy=1   PA        10        10
# 123              nas_ft  smallprob  Static,policy=1   VA        10        10
# 124              nas_ft  smallprob  Static,policy=2   PA        10        10
# 125              nas_ft  smallprob  Static,policy=2   VA        10        10
# 126              nas_lu  largeprob  Static,policy=0   PA        10        10
# 127              nas_lu  largeprob  Static,policy=0   VA        10        10
# 128              nas_lu  largeprob  Static,policy=1   PA        10        10
# 129              nas_lu  largeprob  Static,policy=1   VA        10        10
# 130              nas_lu  largeprob  Static,policy=2   PA         9         9
# 131              nas_lu  largeprob  Static,policy=2   VA         9         9
# 132              nas_lu    medprob  Static,policy=0   PA        10        10
# 133              nas_lu    medprob  Static,policy=0   VA        10        10
# 134              nas_lu    medprob  Static,policy=1   PA        10        10
# 135              nas_lu    medprob  Static,policy=1   VA        10        10
# 136              nas_lu    medprob  Static,policy=2   PA        10        10
# 137              nas_lu    medprob  Static,policy=2   VA        10        10
# 138              nas_lu  smallprob  Static,policy=0   PA        10        10
# 139              nas_lu  smallprob  Static,policy=0   VA        10        10
# 140              nas_lu  smallprob  Static,policy=1   PA        10        10
# 141              nas_lu  smallprob  Static,policy=1   VA        10        10
# 142              nas_lu  smallprob  Static,policy=2   PA        10        10
# 143              nas_lu  smallprob  Static,policy=2   VA        10        10
# 144              nas_mg  largeprob  Static,policy=0   PA        10        10
# 145              nas_mg  largeprob  Static,policy=0   VA        10        10
# 146              nas_mg  largeprob  Static,policy=1   PA        10        10
# 147              nas_mg  largeprob  Static,policy=1   VA        10        10
# 148              nas_mg  largeprob  Static,policy=2   PA         4         4
# 149              nas_mg  largeprob  Static,policy=2   VA         4         4
# 150              nas_mg    medprob  Static,policy=0   PA        10        10
# 151              nas_mg    medprob  Static,policy=0   VA        10        10
# 152              nas_mg    medprob  Static,policy=1   PA        10        10
# 153              nas_mg    medprob  Static,policy=1   VA        10        10
# 154              nas_mg    medprob  Static,policy=2   PA         4         4
# 155              nas_mg    medprob  Static,policy=2   VA         4         4
# 156              nas_mg  smallprob  Static,policy=0   PA        10        10
# 157              nas_mg  smallprob  Static,policy=0   VA        10        10
# 158              nas_mg  smallprob  Static,policy=1   PA        10        10
# 159              nas_mg  smallprob  Static,policy=1   VA        10        10
# 160              nas_mg  smallprob  Static,policy=2   PA         4         4
# 161              nas_mg  smallprob  Static,policy=2   VA         4         4
# 162              nas_sp  largeprob  Static,policy=0   PA        10        10
# 163              nas_sp  largeprob  Static,policy=0   VA        10        10
# 164              nas_sp  largeprob  Static,policy=1   PA        10        10
# 165              nas_sp  largeprob  Static,policy=1   VA        10        10
# 166              nas_sp  largeprob  Static,policy=2   PA         4         4
# 167              nas_sp  largeprob  Static,policy=2   VA         4         4
# 168              nas_sp    medprob  Static,policy=0   PA        10        10
# 169              nas_sp    medprob  Static,policy=0   VA        10        10
# 170              nas_sp    medprob  Static,policy=1   PA        10        10
# 171              nas_sp    medprob  Static,policy=1   VA        10        10
# 172              nas_sp    medprob  Static,policy=2   PA        10        10
# 173              nas_sp    medprob  Static,policy=2   VA        10        10
# 174              nas_sp  smallprob  Static,policy=0   PA        10        10
# 175              nas_sp  smallprob  Static,policy=0   VA        10        10
# 176              nas_sp  smallprob  Static,policy=1   PA        10        10
# 177              nas_sp  smallprob  Static,policy=1   VA        10        10
# 178              nas_sp  smallprob  Static,policy=2   PA        10        10
# 179              nas_sp  smallprob  Static,policy=2   VA        10        10
# 180         quicksilver  largeprob  Static,policy=0   PA        10        10
# 181         quicksilver  largeprob  Static,policy=0   VA        10        10
# 182         quicksilver  largeprob  Static,policy=1   PA        10        10
# 183         quicksilver  largeprob  Static,policy=1   VA        10        10
# 184         quicksilver  largeprob  Static,policy=2   PA         4         4
# 185         quicksilver  largeprob  Static,policy=2   VA         4         4
# 186         quicksilver    medprob  Static,policy=0   PA        10        10
# 187         quicksilver    medprob  Static,policy=0   VA        10        10
# 188         quicksilver    medprob  Static,policy=1   PA        10        10
# 189         quicksilver    medprob  Static,policy=1   VA        10        10
# 190         quicksilver    medprob  Static,policy=2   PA         4         4
# 191         quicksilver    medprob  Static,policy=2   VA         4         4
# 192         quicksilver  smallprob  Static,policy=0   PA        10        10
# 193         quicksilver  smallprob  Static,policy=0   VA        10        10
# 194         quicksilver  smallprob  Static,policy=1   PA        10        10
# 195         quicksilver  smallprob  Static,policy=1   VA        10        10
# 196         quicksilver  smallprob  Static,policy=2   PA         4         4
# 197         quicksilver  smallprob  Static,policy=2   VA         4         4
# 198         rodinia_cfd  largeprob  Static,policy=0   PA        10        10
# 199         rodinia_cfd  largeprob  Static,policy=0   VA        10        10
# 200         rodinia_cfd  largeprob  Static,policy=1   PA        10        10
# 201         rodinia_cfd  largeprob  Static,policy=1   VA        10        10
# 202         rodinia_cfd  largeprob  Static,policy=2   PA         4         4
# 203         rodinia_cfd  largeprob  Static,policy=2   VA         4         4
# 204         rodinia_cfd    medprob  Static,policy=0   PA        10        10
# 205         rodinia_cfd    medprob  Static,policy=0   VA        10        10
# 206         rodinia_cfd    medprob  Static,policy=1   PA        10        10
# 207         rodinia_cfd    medprob  Static,policy=1   VA        10        10
# 208         rodinia_cfd    medprob  Static,policy=2   PA         4         4
# 209         rodinia_cfd    medprob  Static,policy=2   VA         4         4
# 210         rodinia_cfd  smallprob  Static,policy=0   PA        10        10
# 211         rodinia_cfd  smallprob  Static,policy=0   VA        10        10
# 212         rodinia_cfd  smallprob  Static,policy=1   PA        10        10
# 213         rodinia_cfd  smallprob  Static,policy=1   VA        10        10
# 214         rodinia_cfd  smallprob  Static,policy=2   PA         4         4
# 215         rodinia_cfd  smallprob  Static,policy=2   VA         4         4
# 216   rodinia_heartwall  largeprob  Static,policy=0   PA        10        10
# 217   rodinia_heartwall  largeprob  Static,policy=0   VA        10        10
# 218   rodinia_heartwall  largeprob  Static,policy=1   PA        10        10
# 219   rodinia_heartwall  largeprob  Static,policy=1   VA        10        10
# 220   rodinia_heartwall  largeprob  Static,policy=2   PA         4         4
# 221   rodinia_heartwall  largeprob  Static,policy=2   VA         4         4
# 222   rodinia_heartwall    medprob  Static,policy=0   PA        10        10
# 223   rodinia_heartwall    medprob  Static,policy=0   VA        10        10
# 224   rodinia_heartwall    medprob  Static,policy=1   PA        10        10
# 225   rodinia_heartwall    medprob  Static,policy=1   VA        10        10
# 226   rodinia_heartwall    medprob  Static,policy=2   PA         4         4
# 227   rodinia_heartwall    medprob  Static,policy=2   VA         4         4
# 228   rodinia_heartwall  smallprob  Static,policy=0   PA        10        10
# 229   rodinia_heartwall  smallprob  Static,policy=0   VA        10        10
# 230   rodinia_heartwall  smallprob  Static,policy=1   PA        10        10
# 231   rodinia_heartwall  smallprob  Static,policy=1   VA        10        10
# 232   rodinia_heartwall  smallprob  Static,policy=2   PA         4         4
# 233   rodinia_heartwall  smallprob  Static,policy=2   VA         4         4
# 234   rodinia_leukocyte  largeprob  Static,policy=0   PA        10        10
# 235   rodinia_leukocyte  largeprob  Static,policy=0   VA        10        10
# 236   rodinia_leukocyte  largeprob  Static,policy=1   PA        10        10
# 237   rodinia_leukocyte  largeprob  Static,policy=1   VA        10        10
# 238   rodinia_leukocyte  largeprob  Static,policy=2   PA         4         4
# 239   rodinia_leukocyte  largeprob  Static,policy=2   VA         4         4
# 240   rodinia_leukocyte    medprob  Static,policy=0   PA        10        10
# 241   rodinia_leukocyte    medprob  Static,policy=0   VA        10        10
# 242   rodinia_leukocyte    medprob  Static,policy=1   PA        10        10
# 243   rodinia_leukocyte    medprob  Static,policy=1   VA        10        10
# 244   rodinia_leukocyte    medprob  Static,policy=2   PA         4         4
# 245   rodinia_leukocyte    medprob  Static,policy=2   VA         4         4
# 246   rodinia_leukocyte  smallprob  Static,policy=0   PA        10        10
# 247   rodinia_leukocyte  smallprob  Static,policy=0   VA        10        10
# 248   rodinia_leukocyte  smallprob  Static,policy=1   PA        10        10
# 249   rodinia_leukocyte  smallprob  Static,policy=1   VA        10        10
# 250   rodinia_leukocyte  smallprob  Static,policy=2   PA         4         4
# 251   rodinia_leukocyte  smallprob  Static,policy=2   VA         4         4
# 252         rodinia_lud  largeprob  Static,policy=0   PA        10        10
# 253         rodinia_lud  largeprob  Static,policy=0   VA        10        10
# 254         rodinia_lud  largeprob  Static,policy=1   PA        10        10
# 255         rodinia_lud  largeprob  Static,policy=1   VA        10        10
# 256         rodinia_lud  largeprob  Static,policy=2   PA         4         4
# 257         rodinia_lud  largeprob  Static,policy=2   VA         4         4
# 258         rodinia_lud    medprob  Static,policy=0   PA        10        10
# 259         rodinia_lud    medprob  Static,policy=0   VA        10        10
# 260         rodinia_lud    medprob  Static,policy=1   PA        10        10
# 261         rodinia_lud    medprob  Static,policy=1   VA        10        10
# 262         rodinia_lud    medprob  Static,policy=2   PA         4         4
# 263         rodinia_lud    medprob  Static,policy=2   VA         4         4
# 264         rodinia_lud  smallprob  Static,policy=0   PA        10        10
# 265         rodinia_lud  smallprob  Static,policy=0   VA        10        10
# 266         rodinia_lud  smallprob  Static,policy=1   PA        10        10
# 267         rodinia_lud  smallprob  Static,policy=1   VA        10        10
# 268         rodinia_lud  smallprob  Static,policy=2   PA         4         4
# 269         rodinia_lud  smallprob  Static,policy=2   VA         4         4
# 270  rodinia_pathfinder  largeprob  Static,policy=0   PA        10        10
# 271  rodinia_pathfinder  largeprob  Static,policy=0   VA        10        10
# 272  rodinia_pathfinder  largeprob  Static,policy=1   PA        10        10
# 273  rodinia_pathfinder  largeprob  Static,policy=1   VA        10        10
# 274  rodinia_pathfinder  largeprob  Static,policy=2   PA         4         4
# 275  rodinia_pathfinder  largeprob  Static,policy=2   VA         4         4
# 276  rodinia_pathfinder    medprob  Static,policy=0   PA        10        10
# 277  rodinia_pathfinder    medprob  Static,policy=0   VA        10        10
# 278  rodinia_pathfinder    medprob  Static,policy=1   PA        10        10
# 279  rodinia_pathfinder    medprob  Static,policy=1   VA        10        10
# 280  rodinia_pathfinder    medprob  Static,policy=2   PA         4         4
# 281  rodinia_pathfinder    medprob  Static,policy=2   VA         4         4
# 282  rodinia_pathfinder  smallprob  Static,policy=0   PA        10        10
# 283  rodinia_pathfinder  smallprob  Static,policy=0   VA        10        10
# 284  rodinia_pathfinder  smallprob  Static,policy=1   PA        10        10
# 285  rodinia_pathfinder  smallprob  Static,policy=1   VA        10        10
# 286  rodinia_pathfinder  smallprob  Static,policy=2   PA         4         4
# 287  rodinia_pathfinder  smallprob  Static,policy=2   VA         4         4
# 288             xsbench  largeprob  Static,policy=0   PA        10        10
# 289             xsbench  largeprob  Static,policy=0   VA        10        10
# 290             xsbench  largeprob  Static,policy=1   PA        10        10
# 291             xsbench  largeprob  Static,policy=1   VA        10        10
# 292             xsbench  largeprob  Static,policy=2   PA         4         4
# 293             xsbench  largeprob  Static,policy=2   VA         4         4
# 294             xsbench    medprob  Static,policy=0   PA        10        10
# 295             xsbench    medprob  Static,policy=0   VA        10        10
# 296             xsbench    medprob  Static,policy=1   PA        10        10
# 297             xsbench    medprob  Static,policy=1   VA        10        10
# 298             xsbench    medprob  Static,policy=2   PA         4         4
# 299             xsbench    medprob  Static,policy=2   VA         4         4
# 300             xsbench  smallprob  Static,policy=0   PA        10        10
# 301             xsbench  smallprob  Static,policy=0   VA        10        10
# 302             xsbench  smallprob  Static,policy=1   PA        10        10
# 303             xsbench  smallprob  Static,policy=1   VA        10        10
# 304             xsbench  smallprob  Static,policy=2   PA         4         4
# 305             xsbench  smallprob  Static,policy=2   VA         4         4
#    progname   probSize           policy  trialnum    eteXtime type
# 10     comd  largeprob  Static,policy=0         0  743.096055   PA
# 0      comd  largeprob  Static,policy=0         0  742.975929   VA
# 12     comd  largeprob  Static,policy=0         1  746.783867   PA
# 1      comd  largeprob  Static,policy=0         1  746.078329   VA
# 11     comd  largeprob  Static,policy=0         2  744.909844   PA
#                progname   probSize           policy type  mean_etextime  \
# 0                  comd  largeprob  Static,policy=0   PA     744.738542
# 1                  comd  largeprob  Static,policy=0   VA     745.009992
# 2                  comd  largeprob  Static,policy=1   PA    1307.832544
# 3                  comd  largeprob  Static,policy=1   VA    1303.335991
# 4                  comd  largeprob  Static,policy=2   PA   17475.221962
# 5                  comd  largeprob  Static,policy=2   VA   17542.402076
# 6                  comd    medprob  Static,policy=0   PA     100.425379
# 7                  comd    medprob  Static,policy=0   VA     100.149889
# 8                  comd    medprob  Static,policy=1   PA     165.661469
# 9                  comd    medprob  Static,policy=1   VA     165.637322
# 10                 comd    medprob  Static,policy=2   PA    2053.212718
# 11                 comd    medprob  Static,policy=2   VA    2064.644197
# 12                 comd  smallprob  Static,policy=0   PA      13.344295
# 13                 comd  smallprob  Static,policy=0   VA      13.254320
# 14                 comd  smallprob  Static,policy=1   PA      22.850779
# 15                 comd  smallprob  Static,policy=1   VA      22.811003
# 16                 comd  smallprob  Static,policy=2   PA     257.337677
# 17                 comd  smallprob  Static,policy=2   VA     259.951175
# 18               lulesh  largeprob  Static,policy=0   PA     203.250130
# 19               lulesh  largeprob  Static,policy=0   VA     197.078807
# 20               lulesh  largeprob  Static,policy=1   PA     165.690923
# 21               lulesh  largeprob  Static,policy=1   VA     156.661645
# 22               lulesh  largeprob  Static,policy=2   PA     727.129500
# 23               lulesh  largeprob  Static,policy=2   VA     715.157238
# 24               lulesh    medprob  Static,policy=0   PA     154.404973
# 25               lulesh    medprob  Static,policy=0   VA     146.874956
# 26               lulesh    medprob  Static,policy=1   PA     101.138784
# 27               lulesh    medprob  Static,policy=1   VA      97.929175
# 28               lulesh    medprob  Static,policy=2   PA     244.727095
# 29               lulesh    medprob  Static,policy=2   VA     243.989622
# 30               lulesh  smallprob  Static,policy=0   PA     123.218228
# 31               lulesh  smallprob  Static,policy=0   VA     118.316951
# 32               lulesh  smallprob  Static,policy=1   PA      70.973525
# 33               lulesh  smallprob  Static,policy=1   VA      68.144365
# 34               lulesh  smallprob  Static,policy=2   PA      52.883827
# 35               lulesh  smallprob  Static,policy=2   VA      52.135422
# 36               minife  largeprob  Static,policy=0   PA     152.168202
# 37               minife  largeprob  Static,policy=0   VA     149.160272
# 38               minife  largeprob  Static,policy=1   PA     158.536979
# 39               minife  largeprob  Static,policy=1   VA     158.602092
# 40               minife  largeprob  Static,policy=2   PA     996.195628
# 41               minife  largeprob  Static,policy=2   VA    1004.980809
# 42               minife    medprob  Static,policy=0   PA      41.977061
# 43               minife    medprob  Static,policy=0   VA      41.882595
# 44               minife    medprob  Static,policy=1   PA      40.501927
# 45               minife    medprob  Static,policy=1   VA      40.560081
# 46               minife    medprob  Static,policy=2   PA     244.033182
# 47               minife    medprob  Static,policy=2   VA     244.364076
# 48               minife  smallprob  Static,policy=0   PA       2.786124
# 49               minife  smallprob  Static,policy=0   VA       2.755625
# 50               minife  smallprob  Static,policy=1   PA       4.461481
# 51               minife  smallprob  Static,policy=1   VA       4.434647
# 52               minife  smallprob  Static,policy=2   PA      26.340671
# 53               minife  smallprob  Static,policy=2   VA      27.731837
# 54               nas_bt  largeprob  Static,policy=0   PA    1316.021000
# 55               nas_bt  largeprob  Static,policy=0   VA    1312.910000
# 56               nas_bt  largeprob  Static,policy=1   PA    2494.878000
# 57               nas_bt  largeprob  Static,policy=1   VA    2530.686000
# 58               nas_bt  largeprob  Static,policy=2   PA   33535.237500
# 59               nas_bt  largeprob  Static,policy=2   VA   33526.680000
# 60               nas_bt    medprob  Static,policy=0   PA      64.899000
# 61               nas_bt    medprob  Static,policy=0   VA      65.174000
# 62               nas_bt    medprob  Static,policy=1   PA     114.150000
# 63               nas_bt    medprob  Static,policy=1   VA     115.299000
# 64               nas_bt    medprob  Static,policy=2   PA    1477.927000
# 65               nas_bt    medprob  Static,policy=2   VA    1477.268000
# 66               nas_bt  smallprob  Static,policy=0   PA      14.569000
# 67               nas_bt  smallprob  Static,policy=0   VA      14.438000
# 68               nas_bt  smallprob  Static,policy=1   PA      28.782000
# 69               nas_bt  smallprob  Static,policy=1   VA      28.728000
# 70               nas_bt  smallprob  Static,policy=2   PA     356.994000
# 71               nas_bt  smallprob  Static,policy=2   VA     358.443000
# 72               nas_cg  largeprob  Static,policy=0   PA     341.493000
# 73               nas_cg  largeprob  Static,policy=0   VA     339.765000
# 74               nas_cg  largeprob  Static,policy=1   PA     681.918000
# 75               nas_cg  largeprob  Static,policy=1   VA     682.772000
# 76               nas_cg  largeprob  Static,policy=2   PA    9795.089000
# 77               nas_cg  largeprob  Static,policy=2   VA    9804.686000
# 78               nas_cg    medprob  Static,policy=0   PA      12.314000
# 79               nas_cg    medprob  Static,policy=0   VA      12.038000
# 80               nas_cg    medprob  Static,policy=1   PA      23.427000
# 81               nas_cg    medprob  Static,policy=1   VA      23.360000
# 82               nas_cg    medprob  Static,policy=2   PA     313.374000
# 83               nas_cg    medprob  Static,policy=2   VA     313.974000
# 84               nas_cg  smallprob  Static,policy=0   PA       4.805000
# 85               nas_cg  smallprob  Static,policy=0   VA       4.524000
# 86               nas_cg  smallprob  Static,policy=1   PA       8.712000
# 87               nas_cg  smallprob  Static,policy=1   VA       8.681000
# 88               nas_cg  smallprob  Static,policy=2   PA     110.972000
# 89               nas_cg  smallprob  Static,policy=2   VA     111.023000
# 90               nas_ep  largeprob  Static,policy=0   PA     189.973000
# 91               nas_ep  largeprob  Static,policy=0   VA     185.809000
# 92               nas_ep  largeprob  Static,policy=1   PA     368.214000
# 93               nas_ep  largeprob  Static,policy=1   VA     368.122000
# 94               nas_ep  largeprob  Static,policy=2   PA    6617.692000
# 95               nas_ep  largeprob  Static,policy=2   VA    6615.864000
# 96               nas_ep    medprob  Static,policy=0   PA      11.772000
# 97               nas_ep    medprob  Static,policy=0   VA      11.978000
# 98               nas_ep    medprob  Static,policy=1   PA      23.038000
# 99               nas_ep    medprob  Static,policy=1   VA      23.026000
# 100              nas_ep    medprob  Static,policy=2   PA     413.458000
# 101              nas_ep    medprob  Static,policy=2   VA     413.420000
# 102              nas_ep  smallprob  Static,policy=0   PA       2.979000
# 103              nas_ep  smallprob  Static,policy=0   VA       3.003000
# 104              nas_ep  smallprob  Static,policy=1   PA       5.779000
# 105              nas_ep  smallprob  Static,policy=1   VA       5.769000
# 106              nas_ep  smallprob  Static,policy=2   PA     103.411000
# 107              nas_ep  smallprob  Static,policy=2   VA     103.352000
# 108              nas_ft  largeprob  Static,policy=0   PA     342.067000
# 109              nas_ft  largeprob  Static,policy=0   VA     346.868000
# 110              nas_ft  largeprob  Static,policy=1   PA     487.080000
# 111              nas_ft  largeprob  Static,policy=1   VA     491.745000
# 112              nas_ft  largeprob  Static,policy=2   PA    6311.438000
# 113              nas_ft  largeprob  Static,policy=2   VA    6323.516000
# 114              nas_ft    medprob  Static,policy=0   PA      10.657000
# 115              nas_ft    medprob  Static,policy=0   VA      10.871000
# 116              nas_ft    medprob  Static,policy=1   PA      17.381000
# 117              nas_ft    medprob  Static,policy=1   VA      17.466000
# 118              nas_ft    medprob  Static,policy=2   PA     211.465000
# 119              nas_ft    medprob  Static,policy=2   VA     210.302000
# 120              nas_ft  smallprob  Static,policy=0   PA       2.125000
# 121              nas_ft  smallprob  Static,policy=0   VA       2.115000
# 122              nas_ft  smallprob  Static,policy=1   PA       3.780000
# 123              nas_ft  smallprob  Static,policy=1   VA       3.789000
# 124              nas_ft  smallprob  Static,policy=2   PA      45.593000
# 125              nas_ft  smallprob  Static,policy=2   VA      45.269000
# 126              nas_lu  largeprob  Static,policy=0   PA    1073.642000
# 127              nas_lu  largeprob  Static,policy=0   VA    1074.274000
# 128              nas_lu  largeprob  Static,policy=1   PA    2109.169000
# 129              nas_lu  largeprob  Static,policy=1   VA    2107.827000
# 130              nas_lu  largeprob  Static,policy=2   PA   14912.652222
# 131              nas_lu  largeprob  Static,policy=2   VA   15017.045556
# 132              nas_lu    medprob  Static,policy=0   PA      29.488000
# 133              nas_lu    medprob  Static,policy=0   VA      29.526000
# 134              nas_lu    medprob  Static,policy=1   PA      46.519000
# 135              nas_lu    medprob  Static,policy=1   VA      46.494000
# 136              nas_lu    medprob  Static,policy=2   PA     547.880000
# 137              nas_lu    medprob  Static,policy=2   VA     545.951000
# 138              nas_lu  smallprob  Static,policy=0   PA       7.180000
# 139              nas_lu  smallprob  Static,policy=0   VA       7.139000
# 140              nas_lu  smallprob  Static,policy=1   PA      12.299000
# 141              nas_lu  smallprob  Static,policy=1   VA      12.286000
# 142              nas_lu  smallprob  Static,policy=2   PA     135.206000
# 143              nas_lu  smallprob  Static,policy=2   VA     135.449000
# 144              nas_mg  largeprob  Static,policy=0   PA      85.568000
# 145              nas_mg  largeprob  Static,policy=0   VA      85.602000
# 146              nas_mg  largeprob  Static,policy=1   PA     168.289000
# 147              nas_mg  largeprob  Static,policy=1   VA     168.214000
# 148              nas_mg  largeprob  Static,policy=2   PA    1159.715000
# 149              nas_mg  largeprob  Static,policy=2   VA    1161.927500
# 150              nas_mg    medprob  Static,policy=0   PA       4.222000
# 151              nas_mg    medprob  Static,policy=0   VA       4.205000
# 152              nas_mg    medprob  Static,policy=1   PA       8.239000
# 153              nas_mg    medprob  Static,policy=1   VA       8.222000
# 154              nas_mg    medprob  Static,policy=2   PA      48.660000
# 155              nas_mg    medprob  Static,policy=2   VA      49.167500
# 156              nas_mg  smallprob  Static,policy=0   PA       0.469000
# 157              nas_mg  smallprob  Static,policy=0   VA       0.461000
# 158              nas_mg  smallprob  Static,policy=1   PA       0.884000
# 159              nas_mg  smallprob  Static,policy=1   VA       0.879000
# 160              nas_mg  smallprob  Static,policy=2   PA       5.692500
# 161              nas_mg  smallprob  Static,policy=2   VA       5.457500
# 162              nas_sp  largeprob  Static,policy=0   PA    1491.234000
# 163              nas_sp  largeprob  Static,policy=0   VA    1492.486000
# 164              nas_sp  largeprob  Static,policy=1   PA    2778.658000
# 165              nas_sp  largeprob  Static,policy=1   VA    2778.592000
# 166              nas_sp  largeprob  Static,policy=2   PA   12235.630000
# 167              nas_sp  largeprob  Static,policy=2   VA   12392.782500
# 168              nas_sp    medprob  Static,policy=0   PA      66.008000
# 169              nas_sp    medprob  Static,policy=0   VA      65.771000
# 170              nas_sp    medprob  Static,policy=1   PA     113.529000
# 171              nas_sp    medprob  Static,policy=1   VA     113.558000
# 172              nas_sp    medprob  Static,policy=2   PA     567.209000
# 173              nas_sp    medprob  Static,policy=2   VA     573.275000
# 174              nas_sp  smallprob  Static,policy=0   PA       9.259000
# 175              nas_sp  smallprob  Static,policy=0   VA       9.233000
# 176              nas_sp  smallprob  Static,policy=1   PA      18.362000
# 177              nas_sp  smallprob  Static,policy=1   VA      18.329000
# 178              nas_sp  smallprob  Static,policy=2   PA     140.637000
# 179              nas_sp  smallprob  Static,policy=2   VA     143.124000
# 180         quicksilver  largeprob  Static,policy=0   PA     118.216192
# 181         quicksilver  largeprob  Static,policy=0   VA     118.884218
# 182         quicksilver  largeprob  Static,policy=1   PA      80.522523
# 183         quicksilver  largeprob  Static,policy=1   VA      80.393276
# 184         quicksilver  largeprob  Static,policy=2   PA     507.785863
# 185         quicksilver  largeprob  Static,policy=2   VA     509.058078
# 186         quicksilver    medprob  Static,policy=0   PA      59.729533
# 187         quicksilver    medprob  Static,policy=0   VA      60.413004
# 188         quicksilver    medprob  Static,policy=1   PA      40.263620
# 189         quicksilver    medprob  Static,policy=1   VA      40.420137
# 190         quicksilver    medprob  Static,policy=2   PA     253.540587
# 191         quicksilver    medprob  Static,policy=2   VA     258.846894
# 192         quicksilver  smallprob  Static,policy=0   PA      30.671404
# 193         quicksilver  smallprob  Static,policy=0   VA      29.679345
# 194         quicksilver  smallprob  Static,policy=1   PA      20.530031
# 195         quicksilver  smallprob  Static,policy=1   VA      20.322968
# 196         quicksilver  smallprob  Static,policy=2   PA     128.570448
# 197         quicksilver  smallprob  Static,policy=2   VA     130.514487
# 198         rodinia_cfd  largeprob  Static,policy=0   PA      21.653700
# 199         rodinia_cfd  largeprob  Static,policy=0   VA      21.711380
# 200         rodinia_cfd  largeprob  Static,policy=1   PA      36.166050
# 201         rodinia_cfd  largeprob  Static,policy=1   VA      36.249080
# 202         rodinia_cfd  largeprob  Static,policy=2   PA     508.101750
# 203         rodinia_cfd  largeprob  Static,policy=2   VA     504.705000
# 204         rodinia_cfd    medprob  Static,policy=0   PA      11.273570
# 205         rodinia_cfd    medprob  Static,policy=0   VA      11.291810
# 206         rodinia_cfd    medprob  Static,policy=1   PA      17.784140
# 207         rodinia_cfd    medprob  Static,policy=1   VA      17.750220
# 208         rodinia_cfd    medprob  Static,policy=2   PA     233.888750
# 209         rodinia_cfd    medprob  Static,policy=2   VA     234.355250
# 210         rodinia_cfd  smallprob  Static,policy=0   PA       8.575520
# 211         rodinia_cfd  smallprob  Static,policy=0   VA       8.629956
# 212         rodinia_cfd  smallprob  Static,policy=1   PA      13.320450
# 213         rodinia_cfd  smallprob  Static,policy=1   VA      13.316950
# 214         rodinia_cfd  smallprob  Static,policy=2   PA     171.601500
# 215         rodinia_cfd  smallprob  Static,policy=2   VA     171.460000
# 216   rodinia_heartwall  largeprob  Static,policy=0   PA       5.869128
# 217   rodinia_heartwall  largeprob  Static,policy=0   VA       5.840141
# 218   rodinia_heartwall  largeprob  Static,policy=1   PA       8.359540
# 219   rodinia_heartwall  largeprob  Static,policy=1   VA       8.355049
# 220   rodinia_heartwall  largeprob  Static,policy=2   PA     106.136154
# 221   rodinia_heartwall  largeprob  Static,policy=2   VA     107.343335
# 222   rodinia_heartwall    medprob  Static,policy=0   PA       2.948461
# 223   rodinia_heartwall    medprob  Static,policy=0   VA       2.919207
# 224   rodinia_heartwall    medprob  Static,policy=1   PA       4.146718
# 225   rodinia_heartwall    medprob  Static,policy=1   VA       4.174478
# 226   rodinia_heartwall    medprob  Static,policy=2   PA      52.890824
# 227   rodinia_heartwall    medprob  Static,policy=2   VA      53.120090
# 228   rodinia_heartwall  smallprob  Static,policy=0   PA       1.134883
# 229   rodinia_heartwall  smallprob  Static,policy=0   VA       1.132888
# 230   rodinia_heartwall  smallprob  Static,policy=1   PA       1.589740
# 231   rodinia_heartwall  smallprob  Static,policy=1   VA       1.576283
# 232   rodinia_heartwall  smallprob  Static,policy=2   PA      20.083659
# 233   rodinia_heartwall  smallprob  Static,policy=2   VA      20.249359
# 234   rodinia_leukocyte  largeprob  Static,policy=0   PA      72.077194
# 235   rodinia_leukocyte  largeprob  Static,policy=0   VA      71.160808
# 236   rodinia_leukocyte  largeprob  Static,policy=1   PA     130.685924
# 237   rodinia_leukocyte  largeprob  Static,policy=1   VA     130.501855
# 238   rodinia_leukocyte  largeprob  Static,policy=2   PA    1603.711700
# 239   rodinia_leukocyte  largeprob  Static,policy=2   VA    1600.452482
# 240   rodinia_leukocyte    medprob  Static,policy=0   PA      49.673812
# 241   rodinia_leukocyte    medprob  Static,policy=0   VA      47.852601
# 242   rodinia_leukocyte    medprob  Static,policy=1   PA      88.745891
# 243   rodinia_leukocyte    medprob  Static,policy=1   VA      88.691697
# 244   rodinia_leukocyte    medprob  Static,policy=2   PA    1076.497133
# 245   rodinia_leukocyte    medprob  Static,policy=2   VA    1074.594390
# 246   rodinia_leukocyte  smallprob  Static,policy=0   PA      12.598383
# 247   rodinia_leukocyte  smallprob  Static,policy=0   VA      12.239779
# 248   rodinia_leukocyte  smallprob  Static,policy=1   PA      22.768969
# 249   rodinia_leukocyte  smallprob  Static,policy=1   VA      22.737819
# 250   rodinia_leukocyte  smallprob  Static,policy=2   PA     266.118895
# 251   rodinia_leukocyte  smallprob  Static,policy=2   VA     267.704353
# 252         rodinia_lud  largeprob  Static,policy=0   PA     131.647411
# 253         rodinia_lud  largeprob  Static,policy=0   VA     130.283729
# 254         rodinia_lud  largeprob  Static,policy=1   PA     282.643681
# 255         rodinia_lud  largeprob  Static,policy=1   VA     285.385316
# 256         rodinia_lud  largeprob  Static,policy=2   PA    4767.939912
# 257         rodinia_lud  largeprob  Static,policy=2   VA    4761.205388
# 258         rodinia_lud    medprob  Static,policy=0   PA      16.440426
# 259         rodinia_lud    medprob  Static,policy=0   VA      16.630561
# 260         rodinia_lud    medprob  Static,policy=1   PA      32.198403
# 261         rodinia_lud    medprob  Static,policy=1   VA      33.173296
# 262         rodinia_lud    medprob  Static,policy=2   PA     462.105886
# 263         rodinia_lud    medprob  Static,policy=2   VA     512.262860
# 264         rodinia_lud  smallprob  Static,policy=0   PA       0.297211
# 265         rodinia_lud  smallprob  Static,policy=0   VA       0.277699
# 266         rodinia_lud  smallprob  Static,policy=1   PA       0.498431
# 267         rodinia_lud  smallprob  Static,policy=1   VA       0.457223
# 268         rodinia_lud  smallprob  Static,policy=2   PA       5.432863
# 269         rodinia_lud  smallprob  Static,policy=2   VA       5.748674
# 270  rodinia_pathfinder  largeprob  Static,policy=0   PA       0.169970
# 271  rodinia_pathfinder  largeprob  Static,policy=0   VA       0.147493
# 272  rodinia_pathfinder  largeprob  Static,policy=1   PA       0.179717
# 273  rodinia_pathfinder  largeprob  Static,policy=1   VA       0.167525
# 274  rodinia_pathfinder  largeprob  Static,policy=2   PA       1.605400
# 275  rodinia_pathfinder  largeprob  Static,policy=2   VA       1.536082
# 276  rodinia_pathfinder    medprob  Static,policy=0   PA       0.096256
# 277  rodinia_pathfinder    medprob  Static,policy=0   VA       0.073764
# 278  rodinia_pathfinder    medprob  Static,policy=1   PA       0.080161
# 279  rodinia_pathfinder    medprob  Static,policy=1   VA       0.066516
# 280  rodinia_pathfinder    medprob  Static,policy=2   PA       0.409720
# 281  rodinia_pathfinder    medprob  Static,policy=2   VA       0.407620
# 282  rodinia_pathfinder  smallprob  Static,policy=0   PA       0.075516
# 283  rodinia_pathfinder  smallprob  Static,policy=0   VA       0.055229
# 284  rodinia_pathfinder  smallprob  Static,policy=1   PA       0.057401
# 285  rodinia_pathfinder  smallprob  Static,policy=1   VA       0.042363
# 286  rodinia_pathfinder  smallprob  Static,policy=2   PA       0.110076
# 287  rodinia_pathfinder  smallprob  Static,policy=2   VA       0.110291
# 288             xsbench  largeprob  Static,policy=0   PA       1.784100
# 289             xsbench  largeprob  Static,policy=0   VA       1.710700
# 290             xsbench  largeprob  Static,policy=1   PA       2.571700
# 291             xsbench  largeprob  Static,policy=1   VA       2.717200
# 292             xsbench  largeprob  Static,policy=2   PA      44.004250
# 293             xsbench  largeprob  Static,policy=2   VA      42.433750
# 294             xsbench    medprob  Static,policy=0   PA       1.341300
# 295             xsbench    medprob  Static,policy=0   VA       1.339100
# 296             xsbench    medprob  Static,policy=1   PA       2.053100
# 297             xsbench    medprob  Static,policy=1   VA       2.045800
# 298             xsbench    medprob  Static,policy=2   PA      27.745500
# 299             xsbench    medprob  Static,policy=2   VA      27.574500
# 300             xsbench  smallprob  Static,policy=0   PA       0.801100
# 301             xsbench  smallprob  Static,policy=0   VA       0.781100
# 302             xsbench  smallprob  Static,policy=1   PA       1.043500
# 303             xsbench  smallprob  Static,policy=1   VA       1.031100
# 304             xsbench  smallprob  Static,policy=2   PA       8.543250
# 305             xsbench  smallprob  Static,policy=2   VA       8.578750
#
#      std_etextime
# 0        2.688354
# 1        3.061124
# 2       14.706077
# 3        2.518418
# 4      152.596848
# 5      158.526486
# 6        0.172983
# 7        0.150060
# 8        0.313885
# 9        0.244653
# 10      17.014437
# 11      20.817095
# 12       0.099842
# 13       0.038071
# 14       0.065506
# 15       0.047912
# 16       0.555397
# 17       1.893918
# 18       1.578963
# 19       2.501740
# 20       0.884192
# 21       0.624478
# 22       8.072483
# 23       5.073361
# 24       0.818116
# 25       1.026209
# 26       0.808785
# 27       0.619102
# 28       2.454878
# 29       3.826431
# 30       1.200862
# 31       1.084208
# 32       0.398560
# 33       0.763153
# 34       0.709353
# 35       1.129206
# 36       2.746278
# 37       9.451091
# 38       0.845141
# 39       0.883234
# 40      11.387995
# 41       8.878825
# 42       1.523646
# 43       0.524250
# 44       0.157109
# 45       0.209832
# 46       4.280232
# 47       2.978067
# 48       0.035180
# 49       0.013024
# 50       0.034672
# 51       0.014841
# 52       0.779392
# 53       0.274074
# 54      14.766023
# 55       7.199929
# 56      14.300669
# 57      42.838690
# 58     520.449208
# 59     162.440178
# 60       0.666657
# 61       0.255873
# 62       0.148099
# 63       1.470831
# 64      17.736057
# 65      21.985267
# 66       0.119019
# 67       0.123900
# 68       0.079694
# 69       0.070993
# 70       3.125704
# 71       2.169404
# 72       3.614674
# 73       1.073377
# 74       4.499024
# 75       3.400032
# 76      64.042792
# 77      48.386321
# 78       0.195289
# 79       0.024855
# 80       0.207045
# 81       0.047842
# 82       1.905601
# 83       1.681013
# 84       0.262266
# 85       0.116543
# 86       0.294233
# 87       0.032472
# 88       0.893530
# 89       0.672509
# 90      13.239804
# 91       2.411180
# 92       0.179084
# 93       0.160056
# 94       8.186603
# 95       8.168272
# 96       0.354144
# 97       0.567740
# 98       0.012293
# 99       0.015055
# 100      0.671148
# 101      0.565587
# 102      0.053009
# 103      0.210346
# 104      0.008756
# 105      0.003162
# 106      0.130337
# 107      0.120628
# 108     14.999497
# 109     11.920299
# 110      5.621878
# 111      6.454127
# 112     35.948125
# 113     60.161146
# 114      0.787472
# 115      0.178665
# 116      0.278306
# 117      0.173922
# 118      2.377904
# 119      2.083852
# 120      0.077924
# 121      0.074870
# 122      0.032998
# 123      0.029609
# 124      0.824204
# 125      0.850522
# 126      4.236083
# 127      3.954084
# 128      8.421030
# 129     15.030969
# 130    111.402528
# 131    122.605325
# 132      0.573407
# 133      0.342514
# 134      0.062441
# 135      0.071212
# 136      3.107614
# 137      6.629589
# 138      0.206236
# 139      0.042804
# 140      0.085434
# 141      0.034059
# 142      0.716290
# 143      1.899921
# 144      0.134809
# 145      0.393610
# 146      0.623119
# 147      0.602277
# 148     14.701035
# 149      3.995075
# 150      0.023476
# 151      0.022236
# 152      0.048865
# 153      0.048488
# 154      0.221660
# 155      0.310631
# 156      0.005676
# 157      0.003162
# 158      0.009661
# 159      0.007379
# 160      0.321390
# 161      0.028723
# 162      5.191934
# 163      5.784593
# 164      5.736210
# 165      4.852678
# 166     69.854907
# 167     89.539822
# 168      1.061129
# 169      0.742106
# 170      0.174639
# 171      0.250989
# 172      5.952845
# 173      3.357659
# 174      0.135520
# 175      0.058509
# 176      0.041580
# 177      0.057629
# 178      1.342279
# 179      1.063257
# 180      2.438175
# 181      4.282248
# 182      0.810466
# 183      0.643546
# 184      8.568558
# 185      2.736319
# 186      2.288304
# 187      2.087587
# 188      0.325598
# 189      0.355543
# 190      1.227191
# 191      3.903673
# 192      1.265705
# 193      0.980298
# 194      0.200429
# 195      0.122423
# 196      1.632206
# 197      1.394603
# 198      0.064298
# 199      0.091397
# 200      0.171035
# 201      0.206963
# 202      7.903331
# 203      4.610214
# 204      0.032923
# 205      0.049219
# 206      0.032839
# 207      0.059877
# 208      2.908080
# 209      0.538845
# 210      0.038243
# 211      0.063536
# 212      0.018521
# 213      0.037884
# 214      3.039383
# 215      1.781974
# 216      0.041051
# 217      0.023108
# 218      0.082718
# 219      0.060819
# 220      1.362495
# 221      1.269251
# 222      0.045077
# 223      0.010611
# 224      0.005964
# 225      0.047171
# 226      0.659421
# 227      0.552499
# 228      0.049673
# 229      0.035579
# 230      0.038253
# 231      0.017102
# 232      0.331453
# 233      0.489479
# 234      0.076353
# 235      0.158826
# 236      0.206554
# 237      0.063561
# 238     22.927090
# 239     16.031228
# 240      1.456726
# 241      0.057614
# 242      0.027348
# 243      0.044106
# 244     19.214841
# 245      3.284921
# 246      0.403395
# 247      0.036181
# 248      0.006207
# 249      0.009414
# 250      4.121159
# 251      3.792773
# 252      2.213184
# 253      2.533761
# 254     39.805703
# 255     43.096598
# 256     92.228681
# 257     61.322482
# 258      0.648948
# 259      0.877313
# 260      1.846311
# 261      2.253888
# 262    115.955678
# 263     19.299980
# 264      0.015854
# 265      0.014814
# 266      0.055810
# 267      0.029611
# 268      0.742186
# 269      0.494829
# 270      0.006568
# 271      0.004340
# 272      0.006364
# 273      0.006460
# 274      0.038944
# 275      0.091996
# 276      0.004397
# 277      0.002768
# 278      0.002148
# 279      0.002946
# 280      0.043707
# 281      0.044527
# 282      0.004624
# 283      0.002701
# 284      0.004838
# 285      0.004372
# 286      0.000536
# 287      0.001510
# 288      0.080148
# 289      0.057562
# 290      0.023519
# 291      0.471764
# 292      0.295433
# 293      0.398122
# 294      0.008056
# 295      0.057895
# 296      0.004012
# 297      0.007021
# 298      0.274754
# 299      0.020174
# 300      0.005915
# 301      0.002283
# 302      0.004696
# 303      0.007031
# 304      0.002500
# 305      0.024391

# %%
#print(padf)

# now let's lookat the lulesh runs
#print(padf.loc[padf['progname'] == 'lulesh'])

# Let's look at the outlier runs too
print(padf.loc[(padf['perc_xtime_diff'] <= -4) | (padf['perc_xtime_diff'] >= 4)])

print('num cases sampled', len(padf))
# Out:
#                progname   probSize           policy type  mean_etextime  \
# 262         rodinia_lud    medprob  Static,policy=2   PA     462.105886
# 268         rodinia_lud  smallprob  Static,policy=2   PA       5.432863
# 290             xsbench  largeprob  Static,policy=1   PA       2.571700
# 52               minife  smallprob  Static,policy=2   PA      26.340671
# 30               lulesh  smallprob  Static,policy=0   PA     123.218228
# 32               lulesh  smallprob  Static,policy=1   PA      70.973525
# 288             xsbench  largeprob  Static,policy=0   PA       1.784100
# 160              nas_mg  smallprob  Static,policy=2   PA       5.692500
# 274  rodinia_pathfinder  largeprob  Static,policy=2   PA       1.605400
# 24               lulesh    medprob  Static,policy=0   PA     154.404973
# 20               lulesh  largeprob  Static,policy=1   PA     165.690923
# 84               nas_cg  smallprob  Static,policy=0   PA       4.805000
# 264         rodinia_lud  smallprob  Static,policy=0   PA       0.297211
# 272  rodinia_pathfinder  largeprob  Static,policy=1   PA       0.179717
# 266         rodinia_lud  smallprob  Static,policy=1   PA       0.498431
# 270  rodinia_pathfinder  largeprob  Static,policy=0   PA       0.169970
# 278  rodinia_pathfinder    medprob  Static,policy=1   PA       0.080161
# 276  rodinia_pathfinder    medprob  Static,policy=0   PA       0.096256
# 284  rodinia_pathfinder  smallprob  Static,policy=1   PA       0.057401
# 282  rodinia_pathfinder  smallprob  Static,policy=0   PA       0.075516
#
#      std_etextime  pa_minus_va  va_mean_ete_xtime  perc_xtime_diff
# 262    115.955678   -50.156974         512.262860        -9.791257
# 268      0.742186    -0.315811           5.748674        -5.493636
# 290      0.023519    -0.145500           2.717200        -5.354777
# 52       0.779392    -1.391166          27.731837        -5.016494
# 30       1.200862     4.901277         118.316951         4.142498
# 32       0.398560     2.829160          68.144365         4.151716
# 288      0.080148     0.073400           1.710700         4.290641
# 160      0.321390     0.235000           5.457500         4.306001
# 274      0.038944     0.069318           1.536082         4.512633
# 24       0.818116     7.530017         146.874956         5.126822
# 20       0.884192     9.029278         156.661645         5.763554
# 84       0.262266     0.281000           4.524000         6.211317
# 264      0.015854     0.019512           0.277699         7.026161
# 272      0.006364     0.012192           0.167525         7.277545
# 266      0.055810     0.041208           0.457223         9.012787
# 270      0.006568     0.022477           0.147493        15.239503
# 278      0.002148     0.013645           0.066516        20.514193
# 276      0.004397     0.022492           0.073764        30.491297
# 284      0.004838     0.015038           0.042363        35.497791
# 282      0.004624     0.020288           0.055229        36.733486
# num cases sampled 153

# %%
# Now let's zoom in and see the samples for rodinia_lud since it has the highest
# xtime difference across VA and PA
name = 'rodinia_lud'
policy = 'Static,policy=0'
probsize = 'smallprob'
print(df.loc[(df['progname'] == name) & 
             (df['policy'] == policy) & 
             (df['probSize'] == probsize) &
             (df['type'] == 'PA')])

print(df.loc[(df['progname'] == name) & 
             (df['policy'] == policy) & 
             (df['probSize'] == probsize) &
             (df['type'] == 'VA')])
# Out:
#          progname   probSize           policy  trialnum  eteXtime type
# 2315  rodinia_lud  smallprob  Static,policy=0         0  0.321383   PA
# 2319  rodinia_lud  smallprob  Static,policy=0         1  0.303625   PA
# 2317  rodinia_lud  smallprob  Static,policy=0         2  0.300191   PA
# 2316  rodinia_lud  smallprob  Static,policy=0         3  0.279494   PA
# 2312  rodinia_lud  smallprob  Static,policy=0         4  0.275550   PA
# 2313  rodinia_lud  smallprob  Static,policy=0         5  0.283626   PA
# 2314  rodinia_lud  smallprob  Static,policy=0         6  0.312161   PA
# 2318  rodinia_lud  smallprob  Static,policy=0         7  0.301520   PA
# 2321  rodinia_lud  smallprob  Static,policy=0         8  0.282820   PA
# 2320  rodinia_lud  smallprob  Static,policy=0         9  0.311739   PA
#          progname   probSize           policy  trialnum  eteXtime type
# 2309  rodinia_lud  smallprob  Static,policy=0         0  0.287601   VA
# 2310  rodinia_lud  smallprob  Static,policy=0         1  0.279699   VA
# 2311  rodinia_lud  smallprob  Static,policy=0         2  0.259842   VA
# 2304  rodinia_lud  smallprob  Static,policy=0         3  0.247440   VA
# 2305  rodinia_lud  smallprob  Static,policy=0         4  0.287925   VA
# 2306  rodinia_lud  smallprob  Static,policy=0         5  0.265644   VA
# 2307  rodinia_lud  smallprob  Static,policy=0         6  0.291001   VA
# 2302  rodinia_lud  smallprob  Static,policy=0         7  0.284521   VA
# 2308  rodinia_lud  smallprob  Static,policy=0         8  0.288192   VA
# 2303  rodinia_lud  smallprob  Static,policy=0         9  0.285128   VA

# %%
print(df.loc[(df['progname'] == 'quicksilver') & 
             (df['policy'] == 'Static,policy=0') & 
             (df['probSize'] == 'largeprob') &
             (df['type'] == 'PA')])

print(df.loc[(df['progname'] == 'quicksilver') & 
             (df['policy'] == 'Static,policy=0') & 
             (df['probSize'] == 'largeprob') &
             (df['type'] == 'VA')])

print(df.loc[(df['progname'] == 'quicksilver') & 
             (df['type'] == 'VA')])
# Out:
#          progname   probSize           policy  trialnum    eteXtime type
# 1640  quicksilver  largeprob  Static,policy=0         0  114.653583   PA
# 1641  quicksilver  largeprob  Static,policy=0         1  116.636351   PA
# 1642  quicksilver  largeprob  Static,policy=0         2  118.252588   PA
# 1643  quicksilver  largeprob  Static,policy=0         3  121.551012   PA
# 1644  quicksilver  largeprob  Static,policy=0         4  117.921782   PA
# 1645  quicksilver  largeprob  Static,policy=0         5  117.019064   PA
# 1647  quicksilver  largeprob  Static,policy=0         6  117.324534   PA
# 1646  quicksilver  largeprob  Static,policy=0         7  116.032967   PA
# 1648  quicksilver  largeprob  Static,policy=0         8  121.267572   PA
# 1649  quicksilver  largeprob  Static,policy=0         9  121.502470   PA
#          progname   probSize           policy  trialnum    eteXtime type
# 1630  quicksilver  largeprob  Static,policy=0         0  115.766770   VA
# 1632  quicksilver  largeprob  Static,policy=0         1  122.283882   VA
# 1631  quicksilver  largeprob  Static,policy=0         2  115.750341   VA
# 1633  quicksilver  largeprob  Static,policy=0         3  116.547132   VA
# 1634  quicksilver  largeprob  Static,policy=0         4  124.841373   VA
# 1635  quicksilver  largeprob  Static,policy=0         5  118.689988   VA
# 1637  quicksilver  largeprob  Static,policy=0         6  123.334558   VA
# 1638  quicksilver  largeprob  Static,policy=0         7  123.464235   VA
# 1636  quicksilver  largeprob  Static,policy=0         8  112.342914   VA
# 1639  quicksilver  largeprob  Static,policy=0         9  115.820991   VA
#          progname   probSize           policy  trialnum    eteXtime type
# 1630  quicksilver  largeprob  Static,policy=0         0  115.766770   VA
# 1632  quicksilver  largeprob  Static,policy=0         1  122.283882   VA
# 1631  quicksilver  largeprob  Static,policy=0         2  115.750341   VA
# 1633  quicksilver  largeprob  Static,policy=0         3  116.547132   VA
# 1634  quicksilver  largeprob  Static,policy=0         4  124.841373   VA
# 1635  quicksilver  largeprob  Static,policy=0         5  118.689988   VA
# 1637  quicksilver  largeprob  Static,policy=0         6  123.334558   VA
# 1638  quicksilver  largeprob  Static,policy=0         7  123.464235   VA
# 1636  quicksilver  largeprob  Static,policy=0         8  112.342914   VA
# 1639  quicksilver  largeprob  Static,policy=0         9  115.820991   VA
# 1650  quicksilver  largeprob  Static,policy=1         0   79.577402   VA
# 1651  quicksilver  largeprob  Static,policy=1         1   79.565078   VA
# 1652  quicksilver  largeprob  Static,policy=1         2   80.310528   VA
# 1653  quicksilver  largeprob  Static,policy=1         3   81.094613   VA
# 1654  quicksilver  largeprob  Static,policy=1         4   80.205739   VA
# 1655  quicksilver  largeprob  Static,policy=1         5   80.352633   VA
# 1656  quicksilver  largeprob  Static,policy=1         6   80.083018   VA
# 1657  quicksilver  largeprob  Static,policy=1         7   80.142554   VA
# 1658  quicksilver  largeprob  Static,policy=1         8   81.432242   VA
# 1659  quicksilver  largeprob  Static,policy=1         9   81.168957   VA
# 1670  quicksilver  largeprob  Static,policy=2         0  510.547628   VA
# 1671  quicksilver  largeprob  Static,policy=2         1  506.043691   VA
# 1672  quicksilver  largeprob  Static,policy=2         2  512.055946   VA
# 1673  quicksilver  largeprob  Static,policy=2         3  507.585048   VA
# 1678  quicksilver    medprob  Static,policy=0         0   58.171079   VA
# 1680  quicksilver    medprob  Static,policy=0         1   61.438645   VA
# 1679  quicksilver    medprob  Static,policy=0         2   56.736809   VA
# 1681  quicksilver    medprob  Static,policy=0         3   58.940958   VA
# 1682  quicksilver    medprob  Static,policy=0         4   61.693635   VA
# 1683  quicksilver    medprob  Static,policy=0         5   62.590814   VA
# 1684  quicksilver    medprob  Static,policy=0         6   62.880455   VA
# 1685  quicksilver    medprob  Static,policy=0         7   58.984697   VA
# 1686  quicksilver    medprob  Static,policy=0         8   60.569071   VA
# 1687  quicksilver    medprob  Static,policy=0         9   62.123875   VA
# 1698  quicksilver    medprob  Static,policy=1         0   40.368284   VA
# 1699  quicksilver    medprob  Static,policy=1         1   40.574793   VA
# 1700  quicksilver    medprob  Static,policy=1         2   40.218505   VA
# 1701  quicksilver    medprob  Static,policy=1         3   40.363352   VA
# 1702  quicksilver    medprob  Static,policy=1         4   40.851438   VA
# 1703  quicksilver    medprob  Static,policy=1         5   40.496503   VA
# 1704  quicksilver    medprob  Static,policy=1         6   39.960889   VA
# 1705  quicksilver    medprob  Static,policy=1         7   40.620461   VA
# 1707  quicksilver    medprob  Static,policy=1         8   40.930342   VA
# 1706  quicksilver    medprob  Static,policy=1         9   39.816807   VA
# 1718  quicksilver    medprob  Static,policy=2         0  254.242722   VA
# 1719  quicksilver    medprob  Static,policy=2         1  260.761555   VA
# 1720  quicksilver    medprob  Static,policy=2         2  257.256096   VA
# 1721  quicksilver    medprob  Static,policy=2         3  263.127202   VA
# 1726  quicksilver  smallprob  Static,policy=0         0   30.444008   VA
# 1727  quicksilver  smallprob  Static,policy=0         1   31.034950   VA
# 1728  quicksilver  smallprob  Static,policy=0         2   29.961601   VA
# 1729  quicksilver  smallprob  Static,policy=0         3   30.922083   VA
# 1730  quicksilver  smallprob  Static,policy=0         4   29.382260   VA
# 1731  quicksilver  smallprob  Static,policy=0         5   29.736574   VA
# 1732  quicksilver  smallprob  Static,policy=0         6   29.559637   VA
# 1733  quicksilver  smallprob  Static,policy=0         7   28.851914   VA
# 1734  quicksilver  smallprob  Static,policy=0         8   29.078841   VA
# 1735  quicksilver  smallprob  Static,policy=0         9   27.821577   VA
# 1746  quicksilver  smallprob  Static,policy=1         0   20.313381   VA
# 1747  quicksilver  smallprob  Static,policy=1         1   20.456501   VA
# 1748  quicksilver  smallprob  Static,policy=1         2   20.437188   VA
# 1749  quicksilver  smallprob  Static,policy=1         3   20.378109   VA
# 1750  quicksilver  smallprob  Static,policy=1         4   20.099385   VA
# 1751  quicksilver  smallprob  Static,policy=1         5   20.261480   VA
# 1752  quicksilver  smallprob  Static,policy=1         6   20.162142   VA
# 1753  quicksilver  smallprob  Static,policy=1         7   20.461052   VA
# 1754  quicksilver  smallprob  Static,policy=1         8   20.298063   VA
# 1755  quicksilver  smallprob  Static,policy=1         9   20.362381   VA
# 1766  quicksilver  smallprob  Static,policy=2         0  130.297124   VA
# 1767  quicksilver  smallprob  Static,policy=2         1  131.734459   VA
# 1768  quicksilver  smallprob  Static,policy=2         2  128.635402   VA
# 1769  quicksilver  smallprob  Static,policy=2         3  131.390965   VA

# %%
#
