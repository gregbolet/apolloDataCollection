# %%
import os
import argparse
import sys
import time
import pandas as pd
import re
from pathlib import Path

pd.set_option('display.max_rows', None)

APOLLO_DATA_COLLECTION_DIR='/usr/WS2/bolet1/apolloDataCollection'

# Open the PA and VA csv files
VAdf = pd.read_csv(APOLLO_DATA_COLLECTION_DIR+'/static-ETE-XTimeData_VA.csv')
PAdf = pd.read_csv(APOLLO_DATA_COLLECTION_DIR+'/static-ETE-XTimeData_PA.csv')

print('Datasets loaded!')

# Join both datasets together into one
VAdf['type'] = 'VA'
PAdf['type'] = 'PA'

# Just one dataframe to worry about now
rawdf = pd.concat([VAdf, PAdf])

# for now, let's only focus on runs with policy 0
#rawdf = rawdf.loc[rawdf['policy'] == "Static,policy=0"]
# let's drop some programs we don't care about
rawdf = rawdf.loc[rawdf['progname'] != "rodinia_backprop"]
rawdf = rawdf.loc[rawdf['progname'] != "rodinia_nn"]
rawdf = rawdf.loc[rawdf['progname'] != "rodinia_nw"]

# Let's preprocess and remove runs that don't have the same counts
grouped = rawdf.groupby(['progname', 'probSize', 'policy', 'type'])

#print(grouped['type'].count())
counts = grouped.count().reset_index()
print(counts)

# Separate the PAs from the VAs, then subtract
vas = counts.loc[counts['type'] == 'VA']
pas = counts.loc[counts['type'] == 'PA']

# Now let's merge the datasets s.t. we enforce matching trial counts
# this df has all the overlapping cases with the same trial count
# from VA and PA
filtered = pd.merge(vas, pas, how='inner', on=['progname', 'probSize', 'policy', 'trialnum', 'eteXtime'])

targets = filtered[['progname', 'probSize', 'policy']]

# Now let's filter out the parent dataframe
df = pd.merge(targets, rawdf, how='inner', on=['progname', 'probSize', 'policy'])
df = df.sort_values(by=['progname', 'probSize', 'policy', 'trialnum', 'type'])
print(df.head())

#df = df.loc[df['trialnum'] > 3]

# Now that we've cleaned the dataset, lets calculate means
grouped = df.groupby(['progname', 'probSize', 'policy', 'type'])

# Compute avrg and stddev
means = grouped['eteXtime'].mean().reset_index()
stds = grouped['eteXtime'].std().reset_index()

summdf = means.copy()
summdf.drop('eteXtime', axis=1, inplace=True)

summdf['mean_etextime'] = means['eteXtime']
summdf['std_etextime'] = stds['eteXtime']

print(summdf)

vadf = summdf.loc[summdf['type'] == 'VA']
padf = summdf.loc[summdf['type'] == 'PA']

vadf = vadf.sort_values(by=['progname', 'probSize', 'policy'])
padf = padf.sort_values(by=['progname', 'probSize', 'policy'])

# Now let's take the diffs between PA and VA mean xtimes
timeDiffs = padf['mean_etextime'].to_numpy() - vadf['mean_etextime'].to_numpy()

# If any values are greater than 0, then PA was slower
padf['pa_minus_va'] = timeDiffs
padf['va_mean_ete_xtime'] = vadf['mean_etextime'].to_numpy()

# Now let's get percent xtime diff
padf['perc_xtime_diff'] = (timeDiffs * 100) / (vadf['mean_etextime'].to_numpy())

padf = padf.sort_values(by=['perc_xtime_diff'])
# Out:
# Datasets loaded!
#                progname   probSize           policy type  trialnum  eteXtime
# 0                  comd  largeprob  Static,policy=0   PA        10        10
# 1                  comd  largeprob  Static,policy=0   VA        10        10
# 2                  comd  largeprob  Static,policy=1   PA        10        10
# 3                  comd  largeprob  Static,policy=1   VA        10        10
# 4                  comd    medprob  Static,policy=0   PA        10        10
# 5                  comd    medprob  Static,policy=0   VA        10        10
# 6                  comd    medprob  Static,policy=1   PA        10        10
# 7                  comd    medprob  Static,policy=1   VA        10        10
# 8                  comd  smallprob  Static,policy=0   PA        10        10
# 9                  comd  smallprob  Static,policy=0   VA        10        10
# 10                 comd  smallprob  Static,policy=1   PA        10        10
# 11                 comd  smallprob  Static,policy=1   VA        10        10
# 12               lulesh  largeprob  Static,policy=1   PA         1         1
# 13               lulesh  largeprob  Static,policy=1   VA         1         1
# 14               lulesh    medprob  Static,policy=0   PA        10        10
# 15               lulesh    medprob  Static,policy=0   VA        10        10
# 16               lulesh    medprob  Static,policy=1   PA        10        10
# 17               lulesh    medprob  Static,policy=1   VA        10        10
# 18               lulesh  smallprob  Static,policy=0   PA        10        10
# 19               lulesh  smallprob  Static,policy=0   VA        10        10
# 20               lulesh  smallprob  Static,policy=1   PA        10        10
# 21               lulesh  smallprob  Static,policy=1   VA        10        10
# 22               minife  largeprob  Static,policy=0   PA        10        10
# 23               minife  largeprob  Static,policy=0   VA        10        10
# 24               minife  largeprob  Static,policy=1   PA        10        10
# 25               minife  largeprob  Static,policy=1   VA        10        10
# 26               minife    medprob  Static,policy=0   PA        10        10
# 27               minife    medprob  Static,policy=0   VA        10        10
# 28               minife    medprob  Static,policy=1   PA        10        10
# 29               minife    medprob  Static,policy=1   VA        10        10
# 30               minife  smallprob  Static,policy=0   PA        10        10
# 31               minife  smallprob  Static,policy=0   VA        10        10
# 32               minife  smallprob  Static,policy=1   PA        10        10
# 33               minife  smallprob  Static,policy=1   VA        10        10
# 34               nas_bt  largeprob  Static,policy=0   PA        10        10
# 35               nas_bt  largeprob  Static,policy=0   VA        10        10
# 36               nas_bt  largeprob  Static,policy=1   PA        10        10
# 37               nas_bt  largeprob  Static,policy=1   VA        10        10
# 38               nas_bt    medprob  Static,policy=0   PA        10        10
# 39               nas_bt    medprob  Static,policy=0   VA        10        10
# 40               nas_bt    medprob  Static,policy=1   PA        10        10
# 41               nas_bt    medprob  Static,policy=1   VA        10        10
# 42               nas_bt    medprob  Static,policy=2   PA        10        10
# 43               nas_bt    medprob  Static,policy=2   VA        10        10
# 44               nas_bt  smallprob  Static,policy=0   PA        10        10
# 45               nas_bt  smallprob  Static,policy=0   VA        10        10
# 46               nas_bt  smallprob  Static,policy=1   PA        10        10
# 47               nas_bt  smallprob  Static,policy=1   VA        10        10
# 48               nas_bt  smallprob  Static,policy=2   PA        10        10
# 49               nas_bt  smallprob  Static,policy=2   VA        10        10
# 50               nas_cg  largeprob  Static,policy=0   PA        10        10
# 51               nas_cg  largeprob  Static,policy=0   VA        10        10
# 52               nas_cg  largeprob  Static,policy=1   PA        10        10
# 53               nas_cg  largeprob  Static,policy=1   VA        10        10
# 54               nas_cg    medprob  Static,policy=0   PA        10        10
# 55               nas_cg    medprob  Static,policy=0   VA        10        10
# 56               nas_cg    medprob  Static,policy=1   PA        10        10
# 57               nas_cg    medprob  Static,policy=1   VA        10        10
# 58               nas_cg    medprob  Static,policy=2   PA        10        10
# 59               nas_cg    medprob  Static,policy=2   VA        10        10
# 60               nas_cg  smallprob  Static,policy=0   PA        10        10
# 61               nas_cg  smallprob  Static,policy=0   VA        10        10
# 62               nas_cg  smallprob  Static,policy=1   PA        10        10
# 63               nas_cg  smallprob  Static,policy=1   VA        10        10
# 64               nas_cg  smallprob  Static,policy=2   PA        10        10
# 65               nas_cg  smallprob  Static,policy=2   VA        10        10
# 66               nas_ep  largeprob  Static,policy=0   PA        10        10
# 67               nas_ep  largeprob  Static,policy=0   VA        10        10
# 68               nas_ep  largeprob  Static,policy=1   PA        10        10
# 69               nas_ep  largeprob  Static,policy=1   VA        10        10
# 70               nas_ep    medprob  Static,policy=0   PA        10        10
# 71               nas_ep    medprob  Static,policy=0   VA        10        10
# 72               nas_ep    medprob  Static,policy=1   PA        10        10
# 73               nas_ep    medprob  Static,policy=1   VA        10        10
# 74               nas_ep  smallprob  Static,policy=0   PA        10        10
# 75               nas_ep  smallprob  Static,policy=0   VA        10        10
# 76               nas_ep  smallprob  Static,policy=1   PA        10        10
# 77               nas_ep  smallprob  Static,policy=1   VA        10        10
# 78               nas_ft  largeprob  Static,policy=0   PA        10        10
# 79               nas_ft  largeprob  Static,policy=0   VA        10        10
# 80               nas_ft  largeprob  Static,policy=1   PA        10        10
# 81               nas_ft  largeprob  Static,policy=1   VA        10        10
# 82               nas_ft    medprob  Static,policy=0   PA        10        10
# 83               nas_ft    medprob  Static,policy=0   VA        10        10
# 84               nas_ft    medprob  Static,policy=1   PA        10        10
# 85               nas_ft    medprob  Static,policy=1   VA        10        10
# 86               nas_ft  smallprob  Static,policy=0   PA        10        10
# 87               nas_ft  smallprob  Static,policy=0   VA        10        10
# 88               nas_ft  smallprob  Static,policy=1   PA        10        10
# 89               nas_ft  smallprob  Static,policy=1   VA        10        10
# 90               nas_lu  largeprob  Static,policy=0   PA        10        10
# 91               nas_lu  largeprob  Static,policy=0   VA        10        10
# 92               nas_lu  largeprob  Static,policy=1   PA        10        10
# 93               nas_lu  largeprob  Static,policy=1   VA        10        10
# 94               nas_lu    medprob  Static,policy=0   PA        10        10
# 95               nas_lu    medprob  Static,policy=0   VA        10        10
# 96               nas_lu    medprob  Static,policy=1   PA        10        10
# 97               nas_lu    medprob  Static,policy=1   VA        10        10
# 98               nas_lu  smallprob  Static,policy=0   PA        10        10
# 99               nas_lu  smallprob  Static,policy=0   VA        10        10
# 100              nas_lu  smallprob  Static,policy=1   PA        10        10
# 101              nas_lu  smallprob  Static,policy=1   VA        10        10
# 102              nas_mg  largeprob  Static,policy=0   PA        10        10
# 103              nas_mg  largeprob  Static,policy=0   VA        10        10
# 104              nas_mg  largeprob  Static,policy=1   PA        10        10
# 105              nas_mg  largeprob  Static,policy=1   VA        10        10
# 106              nas_mg    medprob  Static,policy=0   PA        10        10
# 107              nas_mg    medprob  Static,policy=0   VA        10        10
# 108              nas_mg    medprob  Static,policy=1   PA        10        10
# 109              nas_mg    medprob  Static,policy=1   VA        10        10
# 110              nas_mg  smallprob  Static,policy=0   PA        10        10
# 111              nas_mg  smallprob  Static,policy=0   VA        10        10
# 112              nas_mg  smallprob  Static,policy=1   PA        10        10
# 113              nas_mg  smallprob  Static,policy=1   VA        10        10
# 114              nas_sp  largeprob  Static,policy=0   PA        10        10
# 115              nas_sp  largeprob  Static,policy=0   VA        10        10
# 116              nas_sp  largeprob  Static,policy=1   PA        10        10
# 117              nas_sp  largeprob  Static,policy=1   VA        10        10
# 118              nas_sp    medprob  Static,policy=0   PA        10        10
# 119              nas_sp    medprob  Static,policy=0   VA        10        10
# 120              nas_sp    medprob  Static,policy=1   PA        10        10
# 121              nas_sp    medprob  Static,policy=1   VA        10        10
# 122              nas_sp  smallprob  Static,policy=0   PA        10        10
# 123              nas_sp  smallprob  Static,policy=0   VA        10        10
# 124              nas_sp  smallprob  Static,policy=1   PA        10        10
# 125              nas_sp  smallprob  Static,policy=1   VA        10        10
# 126         quicksilver  largeprob  Static,policy=0   PA        10        10
# 127         quicksilver  largeprob  Static,policy=0   VA        10        10
# 128         quicksilver  largeprob  Static,policy=1   PA        10        10
# 129         quicksilver  largeprob  Static,policy=1   VA        10        10
# 130         quicksilver    medprob  Static,policy=0   PA        10        10
# 131         quicksilver    medprob  Static,policy=0   VA        10        10
# 132         quicksilver    medprob  Static,policy=1   PA        10        10
# 133         quicksilver    medprob  Static,policy=1   VA        10        10
# 134         quicksilver  smallprob  Static,policy=0   PA        10        10
# 135         quicksilver  smallprob  Static,policy=0   VA        10        10
# 136         quicksilver  smallprob  Static,policy=1   PA        10        10
# 137         quicksilver  smallprob  Static,policy=1   VA        10        10
# 138         rodinia_cfd  largeprob  Static,policy=0   PA        10        10
# 139         rodinia_cfd  largeprob  Static,policy=0   VA        10        10
# 140         rodinia_cfd  largeprob  Static,policy=1   PA        10        10
# 141         rodinia_cfd  largeprob  Static,policy=1   VA        10        10
# 142         rodinia_cfd    medprob  Static,policy=0   PA        10        10
# 143         rodinia_cfd    medprob  Static,policy=0   VA        10        10
# 144         rodinia_cfd    medprob  Static,policy=1   PA        10        10
# 145         rodinia_cfd    medprob  Static,policy=1   VA        10        10
# 146         rodinia_cfd  smallprob  Static,policy=0   PA        10        10
# 147         rodinia_cfd  smallprob  Static,policy=0   VA        10        10
# 148         rodinia_cfd  smallprob  Static,policy=1   PA        10        10
# 149         rodinia_cfd  smallprob  Static,policy=1   VA        10        10
# 150   rodinia_heartwall  largeprob  Static,policy=0   PA        10        10
# 151   rodinia_heartwall  largeprob  Static,policy=0   VA        10        10
# 152   rodinia_heartwall  largeprob  Static,policy=1   PA        10        10
# 153   rodinia_heartwall  largeprob  Static,policy=1   VA        10        10
# 154   rodinia_heartwall    medprob  Static,policy=0   PA        10        10
# 155   rodinia_heartwall    medprob  Static,policy=0   VA        10        10
# 156   rodinia_heartwall    medprob  Static,policy=1   PA        10        10
# 157   rodinia_heartwall    medprob  Static,policy=1   VA        10        10
# 158   rodinia_heartwall  smallprob  Static,policy=0   PA        10        10
# 159   rodinia_heartwall  smallprob  Static,policy=0   VA        10        10
# 160   rodinia_heartwall  smallprob  Static,policy=1   PA        10        10
# 161   rodinia_heartwall  smallprob  Static,policy=1   VA        10        10
# 162   rodinia_leukocyte  largeprob  Static,policy=0   PA        10        10
# 163   rodinia_leukocyte  largeprob  Static,policy=0   VA        10        10
# 164   rodinia_leukocyte  largeprob  Static,policy=1   PA        10        10
# 165   rodinia_leukocyte  largeprob  Static,policy=1   VA        10        10
# 166   rodinia_leukocyte    medprob  Static,policy=0   PA        10        10
# 167   rodinia_leukocyte    medprob  Static,policy=0   VA        10        10
# 168   rodinia_leukocyte    medprob  Static,policy=1   PA        10        10
# 169   rodinia_leukocyte    medprob  Static,policy=1   VA        10        10
# 170   rodinia_leukocyte  smallprob  Static,policy=0   PA        10        10
# 171   rodinia_leukocyte  smallprob  Static,policy=0   VA        10        10
# 172   rodinia_leukocyte  smallprob  Static,policy=1   PA        10        10
# 173   rodinia_leukocyte  smallprob  Static,policy=1   VA        10        10
# 174         rodinia_lud  largeprob  Static,policy=0   PA        10        10
# 175         rodinia_lud  largeprob  Static,policy=0   VA        10        10
# 176         rodinia_lud  largeprob  Static,policy=1   PA        10        10
# 177         rodinia_lud  largeprob  Static,policy=1   VA        10        10
# 178         rodinia_lud    medprob  Static,policy=0   PA        10        10
# 179         rodinia_lud    medprob  Static,policy=0   VA        10        10
# 180         rodinia_lud    medprob  Static,policy=1   PA        10        10
# 181         rodinia_lud    medprob  Static,policy=1   VA        10        10
# 182         rodinia_lud  smallprob  Static,policy=0   PA        10        10
# 183         rodinia_lud  smallprob  Static,policy=0   VA        10        10
# 184         rodinia_lud  smallprob  Static,policy=1   PA        10        10
# 185         rodinia_lud  smallprob  Static,policy=1   VA        10        10
# 186  rodinia_pathfinder  largeprob  Static,policy=0   PA        10        10
# 187  rodinia_pathfinder  largeprob  Static,policy=0   VA        10        10
# 188  rodinia_pathfinder  largeprob  Static,policy=1   PA        10        10
# 189  rodinia_pathfinder  largeprob  Static,policy=1   VA        10        10
# 190  rodinia_pathfinder    medprob  Static,policy=0   PA        10        10
# 191  rodinia_pathfinder    medprob  Static,policy=0   VA        10        10
# 192  rodinia_pathfinder    medprob  Static,policy=1   PA        10        10
# 193  rodinia_pathfinder    medprob  Static,policy=1   VA        10        10
# 194  rodinia_pathfinder  smallprob  Static,policy=0   PA        10        10
# 195  rodinia_pathfinder  smallprob  Static,policy=0   VA        10        10
# 196  rodinia_pathfinder  smallprob  Static,policy=1   PA        10        10
# 197  rodinia_pathfinder  smallprob  Static,policy=1   VA        10        10
# 198             xsbench  largeprob  Static,policy=0   PA        10        10
# 199             xsbench  largeprob  Static,policy=0   VA        10        10
# 200             xsbench  largeprob  Static,policy=1   PA        10        10
# 201             xsbench  largeprob  Static,policy=1   VA        10        10
# 202             xsbench    medprob  Static,policy=0   PA        10        10
# 203             xsbench    medprob  Static,policy=0   VA        10        10
# 204             xsbench    medprob  Static,policy=1   PA        10        10
# 205             xsbench    medprob  Static,policy=1   VA        10        10
# 206             xsbench  smallprob  Static,policy=0   PA        10        10
# 207             xsbench  smallprob  Static,policy=0   VA        10        10
# 208             xsbench  smallprob  Static,policy=1   PA        10        10
# 209             xsbench  smallprob  Static,policy=1   VA        10        10
#    progname   probSize           policy  trialnum    eteXtime type
# 10     comd  largeprob  Static,policy=0         0  743.096055   PA
# 0      comd  largeprob  Static,policy=0         0  742.975929   VA
# 12     comd  largeprob  Static,policy=0         1  746.783867   PA
# 1      comd  largeprob  Static,policy=0         1  746.078329   VA
# 11     comd  largeprob  Static,policy=0         2  744.909844   PA
#                progname   probSize           policy type  mean_etextime  \
# 0                  comd  largeprob  Static,policy=0   PA     744.738542
# 1                  comd  largeprob  Static,policy=0   VA     745.009992
# 2                  comd  largeprob  Static,policy=1   PA    1307.832544
# 3                  comd  largeprob  Static,policy=1   VA    1303.335991
# 4                  comd    medprob  Static,policy=0   PA     100.425379
# 5                  comd    medprob  Static,policy=0   VA     100.149889
# 6                  comd    medprob  Static,policy=1   PA     165.661469
# 7                  comd    medprob  Static,policy=1   VA     165.637322
# 8                  comd  smallprob  Static,policy=0   PA      13.344295
# 9                  comd  smallprob  Static,policy=0   VA      13.254320
# 10                 comd  smallprob  Static,policy=1   PA      22.850779
# 11                 comd  smallprob  Static,policy=1   VA      22.811003
# 12               lulesh  largeprob  Static,policy=1   PA     160.000000
# 13               lulesh  largeprob  Static,policy=1   VA     160.000000
# 14               lulesh    medprob  Static,policy=0   PA     151.000000
# 15               lulesh    medprob  Static,policy=0   VA     150.000000
# 16               lulesh    medprob  Static,policy=1   PA     100.000000
# 17               lulesh    medprob  Static,policy=1   VA      98.400000
# 18               lulesh  smallprob  Static,policy=0   PA     120.000000
# 19               lulesh  smallprob  Static,policy=0   VA     120.000000
# 20               lulesh  smallprob  Static,policy=1   PA      71.100000
# 21               lulesh  smallprob  Static,policy=1   VA      68.100000
# 22               minife  largeprob  Static,policy=0   PA     152.168202
# 23               minife  largeprob  Static,policy=0   VA     149.160272
# 24               minife  largeprob  Static,policy=1   PA     158.536979
# 25               minife  largeprob  Static,policy=1   VA     158.602092
# 26               minife    medprob  Static,policy=0   PA      41.977061
# 27               minife    medprob  Static,policy=0   VA      41.882595
# 28               minife    medprob  Static,policy=1   PA      40.501927
# 29               minife    medprob  Static,policy=1   VA      40.560081
# 30               minife  smallprob  Static,policy=0   PA       2.786124
# 31               minife  smallprob  Static,policy=0   VA       2.755625
# 32               minife  smallprob  Static,policy=1   PA       4.461481
# 33               minife  smallprob  Static,policy=1   VA       4.434647
# 34               nas_bt  largeprob  Static,policy=0   PA    1316.021000
# 35               nas_bt  largeprob  Static,policy=0   VA    1312.910000
# 36               nas_bt  largeprob  Static,policy=1   PA    2494.878000
# 37               nas_bt  largeprob  Static,policy=1   VA    2530.686000
# 38               nas_bt    medprob  Static,policy=0   PA      64.899000
# 39               nas_bt    medprob  Static,policy=0   VA      65.174000
# 40               nas_bt    medprob  Static,policy=1   PA     114.150000
# 41               nas_bt    medprob  Static,policy=1   VA     115.299000
# 42               nas_bt    medprob  Static,policy=2   PA    1477.927000
# 43               nas_bt    medprob  Static,policy=2   VA    1477.268000
# 44               nas_bt  smallprob  Static,policy=0   PA      14.569000
# 45               nas_bt  smallprob  Static,policy=0   VA      14.438000
# 46               nas_bt  smallprob  Static,policy=1   PA      28.782000
# 47               nas_bt  smallprob  Static,policy=1   VA      28.728000
# 48               nas_bt  smallprob  Static,policy=2   PA     356.994000
# 49               nas_bt  smallprob  Static,policy=2   VA     358.443000
# 50               nas_cg  largeprob  Static,policy=0   PA     341.493000
# 51               nas_cg  largeprob  Static,policy=0   VA     339.765000
# 52               nas_cg  largeprob  Static,policy=1   PA     681.918000
# 53               nas_cg  largeprob  Static,policy=1   VA     682.772000
# 54               nas_cg    medprob  Static,policy=0   PA      12.314000
# 55               nas_cg    medprob  Static,policy=0   VA      12.038000
# 56               nas_cg    medprob  Static,policy=1   PA      23.427000
# 57               nas_cg    medprob  Static,policy=1   VA      23.360000
# 58               nas_cg    medprob  Static,policy=2   PA     313.374000
# 59               nas_cg    medprob  Static,policy=2   VA     313.974000
# 60               nas_cg  smallprob  Static,policy=0   PA       4.805000
# 61               nas_cg  smallprob  Static,policy=0   VA       4.524000
# 62               nas_cg  smallprob  Static,policy=1   PA       8.712000
# 63               nas_cg  smallprob  Static,policy=1   VA       8.681000
# 64               nas_cg  smallprob  Static,policy=2   PA     110.972000
# 65               nas_cg  smallprob  Static,policy=2   VA     111.023000
# 66               nas_ep  largeprob  Static,policy=0   PA     189.973000
# 67               nas_ep  largeprob  Static,policy=0   VA     185.809000
# 68               nas_ep  largeprob  Static,policy=1   PA     368.214000
# 69               nas_ep  largeprob  Static,policy=1   VA     368.122000
# 70               nas_ep    medprob  Static,policy=0   PA      11.772000
# 71               nas_ep    medprob  Static,policy=0   VA      11.978000
# 72               nas_ep    medprob  Static,policy=1   PA      23.038000
# 73               nas_ep    medprob  Static,policy=1   VA      23.026000
# 74               nas_ep  smallprob  Static,policy=0   PA       2.979000
# 75               nas_ep  smallprob  Static,policy=0   VA       3.003000
# 76               nas_ep  smallprob  Static,policy=1   PA       5.779000
# 77               nas_ep  smallprob  Static,policy=1   VA       5.769000
# 78               nas_ft  largeprob  Static,policy=0   PA     342.067000
# 79               nas_ft  largeprob  Static,policy=0   VA     346.868000
# 80               nas_ft  largeprob  Static,policy=1   PA     487.080000
# 81               nas_ft  largeprob  Static,policy=1   VA     491.745000
# 82               nas_ft    medprob  Static,policy=0   PA      10.657000
# 83               nas_ft    medprob  Static,policy=0   VA      10.871000
# 84               nas_ft    medprob  Static,policy=1   PA      17.381000
# 85               nas_ft    medprob  Static,policy=1   VA      17.466000
# 86               nas_ft  smallprob  Static,policy=0   PA       2.125000
# 87               nas_ft  smallprob  Static,policy=0   VA       2.115000
# 88               nas_ft  smallprob  Static,policy=1   PA       3.780000
# 89               nas_ft  smallprob  Static,policy=1   VA       3.789000
# 90               nas_lu  largeprob  Static,policy=0   PA    1073.642000
# 91               nas_lu  largeprob  Static,policy=0   VA    1074.274000
# 92               nas_lu  largeprob  Static,policy=1   PA    2109.169000
# 93               nas_lu  largeprob  Static,policy=1   VA    2107.827000
# 94               nas_lu    medprob  Static,policy=0   PA      29.488000
# 95               nas_lu    medprob  Static,policy=0   VA      29.526000
# 96               nas_lu    medprob  Static,policy=1   PA      46.519000
# 97               nas_lu    medprob  Static,policy=1   VA      46.494000
# 98               nas_lu  smallprob  Static,policy=0   PA       7.180000
# 99               nas_lu  smallprob  Static,policy=0   VA       7.139000
# 100              nas_lu  smallprob  Static,policy=1   PA      12.299000
# 101              nas_lu  smallprob  Static,policy=1   VA      12.286000
# 102              nas_mg  largeprob  Static,policy=0   PA      85.568000
# 103              nas_mg  largeprob  Static,policy=0   VA      85.602000
# 104              nas_mg  largeprob  Static,policy=1   PA     168.289000
# 105              nas_mg  largeprob  Static,policy=1   VA     168.214000
# 106              nas_mg    medprob  Static,policy=0   PA       4.222000
# 107              nas_mg    medprob  Static,policy=0   VA       4.205000
# 108              nas_mg    medprob  Static,policy=1   PA       8.239000
# 109              nas_mg    medprob  Static,policy=1   VA       8.222000
# 110              nas_mg  smallprob  Static,policy=0   PA       0.469000
# 111              nas_mg  smallprob  Static,policy=0   VA       0.461000
# 112              nas_mg  smallprob  Static,policy=1   PA       0.884000
# 113              nas_mg  smallprob  Static,policy=1   VA       0.879000
# 114              nas_sp  largeprob  Static,policy=0   PA    1491.234000
# 115              nas_sp  largeprob  Static,policy=0   VA    1492.486000
# 116              nas_sp  largeprob  Static,policy=1   PA    2778.658000
# 117              nas_sp  largeprob  Static,policy=1   VA    2778.592000
# 118              nas_sp    medprob  Static,policy=0   PA      66.008000
# 119              nas_sp    medprob  Static,policy=0   VA      65.771000
# 120              nas_sp    medprob  Static,policy=1   PA     113.529000
# 121              nas_sp    medprob  Static,policy=1   VA     113.558000
# 122              nas_sp  smallprob  Static,policy=0   PA       9.259000
# 123              nas_sp  smallprob  Static,policy=0   VA       9.233000
# 124              nas_sp  smallprob  Static,policy=1   PA      18.362000
# 125              nas_sp  smallprob  Static,policy=1   VA      18.329000
# 126         quicksilver  largeprob  Static,policy=0   PA     118.216192
# 127         quicksilver  largeprob  Static,policy=0   VA     118.884218
# 128         quicksilver  largeprob  Static,policy=1   PA      80.522523
# 129         quicksilver  largeprob  Static,policy=1   VA      80.393276
# 130         quicksilver    medprob  Static,policy=0   PA      59.729533
# 131         quicksilver    medprob  Static,policy=0   VA      60.413004
# 132         quicksilver    medprob  Static,policy=1   PA      40.263620
# 133         quicksilver    medprob  Static,policy=1   VA      40.420137
# 134         quicksilver  smallprob  Static,policy=0   PA      30.671404
# 135         quicksilver  smallprob  Static,policy=0   VA      29.679345
# 136         quicksilver  smallprob  Static,policy=1   PA      20.530031
# 137         quicksilver  smallprob  Static,policy=1   VA      20.322968
# 138         rodinia_cfd  largeprob  Static,policy=0   PA      21.653700
# 139         rodinia_cfd  largeprob  Static,policy=0   VA      21.711380
# 140         rodinia_cfd  largeprob  Static,policy=1   PA      36.166050
# 141         rodinia_cfd  largeprob  Static,policy=1   VA      36.249080
# 142         rodinia_cfd    medprob  Static,policy=0   PA      11.273570
# 143         rodinia_cfd    medprob  Static,policy=0   VA      11.291810
# 144         rodinia_cfd    medprob  Static,policy=1   PA      17.784140
# 145         rodinia_cfd    medprob  Static,policy=1   VA      17.750220
# 146         rodinia_cfd  smallprob  Static,policy=0   PA       8.575520
# 147         rodinia_cfd  smallprob  Static,policy=0   VA       8.629956
# 148         rodinia_cfd  smallprob  Static,policy=1   PA      13.320450
# 149         rodinia_cfd  smallprob  Static,policy=1   VA      13.316950
# 150   rodinia_heartwall  largeprob  Static,policy=0   PA       5.869128
# 151   rodinia_heartwall  largeprob  Static,policy=0   VA       5.840141
# 152   rodinia_heartwall  largeprob  Static,policy=1   PA       8.359540
# 153   rodinia_heartwall  largeprob  Static,policy=1   VA       8.355049
# 154   rodinia_heartwall    medprob  Static,policy=0   PA       2.948461
# 155   rodinia_heartwall    medprob  Static,policy=0   VA       2.919207
# 156   rodinia_heartwall    medprob  Static,policy=1   PA       4.146718
# 157   rodinia_heartwall    medprob  Static,policy=1   VA       4.174478
# 158   rodinia_heartwall  smallprob  Static,policy=0   PA       1.134883
# 159   rodinia_heartwall  smallprob  Static,policy=0   VA       1.132888
# 160   rodinia_heartwall  smallprob  Static,policy=1   PA       1.589740
# 161   rodinia_heartwall  smallprob  Static,policy=1   VA       1.576283
# 162   rodinia_leukocyte  largeprob  Static,policy=0   PA      72.077194
# 163   rodinia_leukocyte  largeprob  Static,policy=0   VA      71.160808
# 164   rodinia_leukocyte  largeprob  Static,policy=1   PA     130.685924
# 165   rodinia_leukocyte  largeprob  Static,policy=1   VA     130.501855
# 166   rodinia_leukocyte    medprob  Static,policy=0   PA      49.673812
# 167   rodinia_leukocyte    medprob  Static,policy=0   VA      47.852601
# 168   rodinia_leukocyte    medprob  Static,policy=1   PA      88.745891
# 169   rodinia_leukocyte    medprob  Static,policy=1   VA      88.691697
# 170   rodinia_leukocyte  smallprob  Static,policy=0   PA      12.598383
# 171   rodinia_leukocyte  smallprob  Static,policy=0   VA      12.239779
# 172   rodinia_leukocyte  smallprob  Static,policy=1   PA      22.768969
# 173   rodinia_leukocyte  smallprob  Static,policy=1   VA      22.737819
# 174         rodinia_lud  largeprob  Static,policy=0   PA     133.403593
# 175         rodinia_lud  largeprob  Static,policy=0   VA     134.311351
# 176         rodinia_lud  largeprob  Static,policy=1   PA     300.246850
# 177         rodinia_lud  largeprob  Static,policy=1   VA     299.188492
# 178         rodinia_lud    medprob  Static,policy=0   PA      17.684142
# 179         rodinia_lud    medprob  Static,policy=0   VA      17.508198
# 180         rodinia_lud    medprob  Static,policy=1   PA      35.930164
# 181         rodinia_lud    medprob  Static,policy=1   VA      36.180118
# 182         rodinia_lud  smallprob  Static,policy=0   PA       0.420590
# 183         rodinia_lud  smallprob  Static,policy=0   VA       0.315726
# 184         rodinia_lud  smallprob  Static,policy=1   PA       0.527267
# 185         rodinia_lud  smallprob  Static,policy=1   VA       0.478211
# 186  rodinia_pathfinder  largeprob  Static,policy=0   PA       0.010569
# 187  rodinia_pathfinder  largeprob  Static,policy=0   VA       0.009845
# 188  rodinia_pathfinder  largeprob  Static,policy=1   PA       0.011155
# 189  rodinia_pathfinder  largeprob  Static,policy=1   VA       0.009891
# 190  rodinia_pathfinder    medprob  Static,policy=0   PA       0.010304
# 191  rodinia_pathfinder    medprob  Static,policy=0   VA       0.009606
# 192  rodinia_pathfinder    medprob  Static,policy=1   PA       0.010328
# 193  rodinia_pathfinder    medprob  Static,policy=1   VA       0.009783
# 194  rodinia_pathfinder  smallprob  Static,policy=0   PA       0.014633
# 195  rodinia_pathfinder  smallprob  Static,policy=0   VA       0.013738
# 196  rodinia_pathfinder  smallprob  Static,policy=1   PA       0.010294
# 197  rodinia_pathfinder  smallprob  Static,policy=1   VA       0.010090
# 198             xsbench  largeprob  Static,policy=0   PA       1.784100
# 199             xsbench  largeprob  Static,policy=0   VA       1.710700
# 200             xsbench  largeprob  Static,policy=1   PA       2.571700
# 201             xsbench  largeprob  Static,policy=1   VA       2.717200
# 202             xsbench    medprob  Static,policy=0   PA       1.341300
# 203             xsbench    medprob  Static,policy=0   VA       1.339100
# 204             xsbench    medprob  Static,policy=1   PA       2.053100
# 205             xsbench    medprob  Static,policy=1   VA       2.045800
# 206             xsbench  smallprob  Static,policy=0   PA       0.801100
# 207             xsbench  smallprob  Static,policy=0   VA       0.781100
# 208             xsbench  smallprob  Static,policy=1   PA       1.043500
# 209             xsbench  smallprob  Static,policy=1   VA       1.031100
#
#      std_etextime
# 0        2.688354
# 1        3.061124
# 2       14.706077
# 3        2.518418
# 4        0.172983
# 5        0.150060
# 6        0.313885
# 7        0.244653
# 8        0.099842
# 9        0.038071
# 10       0.065506
# 11       0.047912
# 12            NaN
# 13            NaN
# 14       3.162278
# 15       0.000000
# 16       0.000000
# 17       0.516398
# 18       0.000000
# 19       0.000000
# 20       0.567646
# 21       0.316228
# 22       2.746278
# 23       9.451091
# 24       0.845141
# 25       0.883234
# 26       1.523646
# 27       0.524250
# 28       0.157109
# 29       0.209832
# 30       0.035180
# 31       0.013024
# 32       0.034672
# 33       0.014841
# 34      14.766023
# 35       7.199929
# 36      14.300669
# 37      42.838690
# 38       0.666657
# 39       0.255873
# 40       0.148099
# 41       1.470831
# 42      17.736057
# 43      21.985267
# 44       0.119019
# 45       0.123900
# 46       0.079694
# 47       0.070993
# 48       3.125704
# 49       2.169404
# 50       3.614674
# 51       1.073377
# 52       4.499024
# 53       3.400032
# 54       0.195289
# 55       0.024855
# 56       0.207045
# 57       0.047842
# 58       1.905601
# 59       1.681013
# 60       0.262266
# 61       0.116543
# 62       0.294233
# 63       0.032472
# 64       0.893530
# 65       0.672509
# 66      13.239804
# 67       2.411180
# 68       0.179084
# 69       0.160056
# 70       0.354144
# 71       0.567740
# 72       0.012293
# 73       0.015055
# 74       0.053009
# 75       0.210346
# 76       0.008756
# 77       0.003162
# 78      14.999497
# 79      11.920299
# 80       5.621878
# 81       6.454127
# 82       0.787472
# 83       0.178665
# 84       0.278306
# 85       0.173922
# 86       0.077924
# 87       0.074870
# 88       0.032998
# 89       0.029609
# 90       4.236083
# 91       3.954084
# 92       8.421030
# 93      15.030969
# 94       0.573407
# 95       0.342514
# 96       0.062441
# 97       0.071212
# 98       0.206236
# 99       0.042804
# 100      0.085434
# 101      0.034059
# 102      0.134809
# 103      0.393610
# 104      0.623119
# 105      0.602277
# 106      0.023476
# 107      0.022236
# 108      0.048865
# 109      0.048488
# 110      0.005676
# 111      0.003162
# 112      0.009661
# 113      0.007379
# 114      5.191934
# 115      5.784593
# 116      5.736210
# 117      4.852678
# 118      1.061129
# 119      0.742106
# 120      0.174639
# 121      0.250989
# 122      0.135520
# 123      0.058509
# 124      0.041580
# 125      0.057629
# 126      2.438175
# 127      4.282248
# 128      0.810466
# 129      0.643546
# 130      2.288304
# 131      2.087587
# 132      0.325598
# 133      0.355543
# 134      1.265705
# 135      0.980298
# 136      0.200429
# 137      0.122423
# 138      0.064298
# 139      0.091397
# 140      0.171035
# 141      0.206963
# 142      0.032923
# 143      0.049219
# 144      0.032839
# 145      0.059877
# 146      0.038243
# 147      0.063536
# 148      0.018521
# 149      0.037884
# 150      0.041051
# 151      0.023108
# 152      0.082718
# 153      0.060819
# 154      0.045077
# 155      0.010611
# 156      0.005964
# 157      0.047171
# 158      0.049673
# 159      0.035579
# 160      0.038253
# 161      0.017102
# 162      0.076353
# 163      0.158826
# 164      0.206554
# 165      0.063561
# 166      1.456726
# 167      0.057614
# 168      0.027348
# 169      0.044106
# 170      0.403395
# 171      0.036181
# 172      0.006207
# 173      0.009414
# 174      3.009407
# 175      2.474338
# 176      2.525679
# 177      3.493951
# 178      0.277292
# 179      0.540017
# 180      0.577604
# 181      1.411363
# 182      0.167961
# 183      0.008539
# 184      0.010595
# 185      0.006501
# 186      0.001001
# 187      0.000227
# 188      0.000351
# 189      0.000453
# 190      0.000334
# 191      0.000405
# 192      0.000489
# 193      0.000360
# 194      0.012214
# 195      0.011170
# 196      0.000513
# 197      0.000265
# 198      0.080148
# 199      0.057562
# 200      0.023519
# 201      0.471764
# 202      0.008056
# 203      0.057895
# 204      0.004012
# 205      0.007021
# 206      0.005915
# 207      0.002283
# 208      0.004696
# 209      0.007031

# %%
#print(padf)

# now let's lookat the lulesh runs
#print(padf.loc[padf['progname'] == 'lulesh'])

# Let's look at the outlier runs too
print(padf.loc[(padf['perc_xtime_diff'] <= -4) | (padf['perc_xtime_diff'] >= 4)])
# Out:
#                progname   probSize           policy type  mean_etextime  \
# 200             xsbench  largeprob  Static,policy=1   PA       2.571700
# 198             xsbench  largeprob  Static,policy=0   PA       1.784100
# 20               lulesh  smallprob  Static,policy=1   PA      71.100000
# 192  rodinia_pathfinder    medprob  Static,policy=1   PA       0.010328
# 60               nas_cg  smallprob  Static,policy=0   PA       4.805000
# 194  rodinia_pathfinder  smallprob  Static,policy=0   PA       0.014633
# 190  rodinia_pathfinder    medprob  Static,policy=0   PA       0.010304
# 186  rodinia_pathfinder  largeprob  Static,policy=0   PA       0.010569
# 184         rodinia_lud  smallprob  Static,policy=1   PA       0.527267
# 188  rodinia_pathfinder  largeprob  Static,policy=1   PA       0.011155
# 182         rodinia_lud  smallprob  Static,policy=0   PA       0.420590
#
#      std_etextime  pa_minus_va  va_mean_ete_xtime  perc_xtime_diff
# 200      0.023519    -0.145500           2.717200        -5.354777
# 198      0.080148     0.073400           1.710700         4.290641
# 20       0.567646     3.000000          68.100000         4.405286
# 192      0.000489     0.000545           0.009783         5.574168
# 60       0.262266     0.281000           4.524000         6.211317
# 194      0.012214     0.000895           0.013738         6.516206
# 190      0.000334     0.000698           0.009606         7.266014
# 186      0.001001     0.000724           0.009845         7.353213
# 184      0.010595     0.049056           0.478211        10.258249
# 188      0.000351     0.001264           0.009891        12.780415
# 182      0.167961     0.104865           0.315726        33.213904

# %%
# Now let's zoom in and see the samples for rodinia_lud since it has the highest
# xtime difference across VA and PA

print(df.loc[(df['progname'] == 'rodinia_lud') & 
             (df['policy'] == 'Static,policy=0') & 
             (df['probSize'] == 'smallprob') &
             (df['type'] == 'PA')])

print(df.loc[(df['progname'] == 'rodinia_lud') & 
             (df['policy'] == 'Static,policy=0') & 
             (df['probSize'] == 'smallprob') &
             (df['type'] == 'VA')])
# Out:
#          progname   probSize           policy  trialnum  eteXtime type
# 1812  rodinia_lud  smallprob  Static,policy=0         0  0.447834   PA
# 1813  rodinia_lud  smallprob  Static,policy=0         1  0.347258   PA
# 1814  rodinia_lud  smallprob  Static,policy=0         2  0.357280   PA
# 1815  rodinia_lud  smallprob  Static,policy=0         3  0.891652   PA
# 1816  rodinia_lud  smallprob  Static,policy=0         4  0.360750   PA
# 1817  rodinia_lud  smallprob  Static,policy=0         5  0.360228   PA
# 1818  rodinia_lud  smallprob  Static,policy=0         6  0.364948   PA
# 1819  rodinia_lud  smallprob  Static,policy=0         7  0.353635   PA
# 1820  rodinia_lud  smallprob  Static,policy=0         8  0.360270   PA
# 1821  rodinia_lud  smallprob  Static,policy=0         9  0.362050   PA
#          progname   probSize           policy  trialnum  eteXtime type
# 1802  rodinia_lud  smallprob  Static,policy=0         0  0.339245   VA
# 1803  rodinia_lud  smallprob  Static,policy=0         1  0.312462   VA
# 1804  rodinia_lud  smallprob  Static,policy=0         2  0.313895   VA
# 1805  rodinia_lud  smallprob  Static,policy=0         3  0.312354   VA
# 1806  rodinia_lud  smallprob  Static,policy=0         4  0.318116   VA
# 1807  rodinia_lud  smallprob  Static,policy=0         5  0.311607   VA
# 1808  rodinia_lud  smallprob  Static,policy=0         6  0.315116   VA
# 1809  rodinia_lud  smallprob  Static,policy=0         7  0.311258   VA
# 1810  rodinia_lud  smallprob  Static,policy=0         8  0.312181   VA
# 1811  rodinia_lud  smallprob  Static,policy=0         9  0.311022   VA

# %%
print(df.loc[(df['progname'] == 'quicksilver') & 
             (df['policy'] == 'Static,policy=0') & 
             (df['probSize'] == 'largeprob') &
             (df['type'] == 'PA')])

print(df.loc[(df['progname'] == 'quicksilver') & 
             (df['policy'] == 'Static,policy=0') & 
             (df['probSize'] == 'largeprob') &
             (df['type'] == 'VA')])

print(df.loc[(df['progname'] == 'quicksilver') & 
             (df['type'] == 'VA')])
# Out:
#          progname   probSize           policy  trialnum    eteXtime type
# 1252  quicksilver  largeprob  Static,policy=0         0  114.653583   PA
# 1253  quicksilver  largeprob  Static,policy=0         1  116.636351   PA
# 1254  quicksilver  largeprob  Static,policy=0         2  118.252588   PA
# 1255  quicksilver  largeprob  Static,policy=0         3  121.551012   PA
# 1256  quicksilver  largeprob  Static,policy=0         4  117.921782   PA
# 1257  quicksilver  largeprob  Static,policy=0         5  117.019064   PA
# 1259  quicksilver  largeprob  Static,policy=0         6  117.324534   PA
# 1258  quicksilver  largeprob  Static,policy=0         7  116.032967   PA
# 1260  quicksilver  largeprob  Static,policy=0         8  121.267572   PA
# 1261  quicksilver  largeprob  Static,policy=0         9  121.502470   PA
#          progname   probSize           policy  trialnum    eteXtime type
# 1242  quicksilver  largeprob  Static,policy=0         0  115.766770   VA
# 1244  quicksilver  largeprob  Static,policy=0         1  122.283882   VA
# 1243  quicksilver  largeprob  Static,policy=0         2  115.750341   VA
# 1245  quicksilver  largeprob  Static,policy=0         3  116.547132   VA
# 1246  quicksilver  largeprob  Static,policy=0         4  124.841373   VA
# 1247  quicksilver  largeprob  Static,policy=0         5  118.689988   VA
# 1249  quicksilver  largeprob  Static,policy=0         6  123.334558   VA
# 1250  quicksilver  largeprob  Static,policy=0         7  123.464235   VA
# 1248  quicksilver  largeprob  Static,policy=0         8  112.342914   VA
# 1251  quicksilver  largeprob  Static,policy=0         9  115.820991   VA
#          progname   probSize           policy  trialnum    eteXtime type
# 1242  quicksilver  largeprob  Static,policy=0         0  115.766770   VA
# 1244  quicksilver  largeprob  Static,policy=0         1  122.283882   VA
# 1243  quicksilver  largeprob  Static,policy=0         2  115.750341   VA
# 1245  quicksilver  largeprob  Static,policy=0         3  116.547132   VA
# 1246  quicksilver  largeprob  Static,policy=0         4  124.841373   VA
# 1247  quicksilver  largeprob  Static,policy=0         5  118.689988   VA
# 1249  quicksilver  largeprob  Static,policy=0         6  123.334558   VA
# 1250  quicksilver  largeprob  Static,policy=0         7  123.464235   VA
# 1248  quicksilver  largeprob  Static,policy=0         8  112.342914   VA
# 1251  quicksilver  largeprob  Static,policy=0         9  115.820991   VA
# 1262  quicksilver  largeprob  Static,policy=1         0   79.577402   VA
# 1263  quicksilver  largeprob  Static,policy=1         1   79.565078   VA
# 1264  quicksilver  largeprob  Static,policy=1         2   80.310528   VA
# 1265  quicksilver  largeprob  Static,policy=1         3   81.094613   VA
# 1266  quicksilver  largeprob  Static,policy=1         4   80.205739   VA
# 1267  quicksilver  largeprob  Static,policy=1         5   80.352633   VA
# 1268  quicksilver  largeprob  Static,policy=1         6   80.083018   VA
# 1269  quicksilver  largeprob  Static,policy=1         7   80.142554   VA
# 1270  quicksilver  largeprob  Static,policy=1         8   81.432242   VA
# 1271  quicksilver  largeprob  Static,policy=1         9   81.168957   VA
# 1282  quicksilver    medprob  Static,policy=0         0   58.171079   VA
# 1284  quicksilver    medprob  Static,policy=0         1   61.438645   VA
# 1283  quicksilver    medprob  Static,policy=0         2   56.736809   VA
# 1285  quicksilver    medprob  Static,policy=0         3   58.940958   VA
# 1286  quicksilver    medprob  Static,policy=0         4   61.693635   VA
# 1287  quicksilver    medprob  Static,policy=0         5   62.590814   VA
# 1288  quicksilver    medprob  Static,policy=0         6   62.880455   VA
# 1289  quicksilver    medprob  Static,policy=0         7   58.984697   VA
# 1290  quicksilver    medprob  Static,policy=0         8   60.569071   VA
# 1291  quicksilver    medprob  Static,policy=0         9   62.123875   VA
# 1302  quicksilver    medprob  Static,policy=1         0   40.368284   VA
# 1303  quicksilver    medprob  Static,policy=1         1   40.574793   VA
# 1304  quicksilver    medprob  Static,policy=1         2   40.218505   VA
# 1305  quicksilver    medprob  Static,policy=1         3   40.363352   VA
# 1306  quicksilver    medprob  Static,policy=1         4   40.851438   VA
# 1307  quicksilver    medprob  Static,policy=1         5   40.496503   VA
# 1308  quicksilver    medprob  Static,policy=1         6   39.960889   VA
# 1309  quicksilver    medprob  Static,policy=1         7   40.620461   VA
# 1311  quicksilver    medprob  Static,policy=1         8   40.930342   VA
# 1310  quicksilver    medprob  Static,policy=1         9   39.816807   VA
# 1322  quicksilver  smallprob  Static,policy=0         0   30.444008   VA
# 1323  quicksilver  smallprob  Static,policy=0         1   31.034950   VA
# 1324  quicksilver  smallprob  Static,policy=0         2   29.961601   VA
# 1325  quicksilver  smallprob  Static,policy=0         3   30.922083   VA
# 1326  quicksilver  smallprob  Static,policy=0         4   29.382260   VA
# 1327  quicksilver  smallprob  Static,policy=0         5   29.736574   VA
# 1328  quicksilver  smallprob  Static,policy=0         6   29.559637   VA
# 1329  quicksilver  smallprob  Static,policy=0         7   28.851914   VA
# 1330  quicksilver  smallprob  Static,policy=0         8   29.078841   VA
# 1331  quicksilver  smallprob  Static,policy=0         9   27.821577   VA
# 1342  quicksilver  smallprob  Static,policy=1         0   20.313381   VA
# 1343  quicksilver  smallprob  Static,policy=1         1   20.456501   VA
# 1344  quicksilver  smallprob  Static,policy=1         2   20.437188   VA
# 1345  quicksilver  smallprob  Static,policy=1         3   20.378109   VA
# 1346  quicksilver  smallprob  Static,policy=1         4   20.099385   VA
# 1347  quicksilver  smallprob  Static,policy=1         5   20.261480   VA
# 1348  quicksilver  smallprob  Static,policy=1         6   20.162142   VA
# 1349  quicksilver  smallprob  Static,policy=1         7   20.461052   VA
# 1350  quicksilver  smallprob  Static,policy=1         8   20.298063   VA
# 1351  quicksilver  smallprob  Static,policy=1         9   20.362381   VA

# %%
#
